# %% [markdown]
# <a href="https://colab.research.google.com/github/neetushibu/IontheFold-Team6/blob/main/SplitFolder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The below script split the files within the folder into batches of 500 within the same subfolder.

# %%
import os
import shutil
from pathlib import Path

def split_files(source_folder, batch_size=500, output_directory=None, start_batch_num=1):
    source_path = Path(source_folder)
    if not source_path.exists():
        print(f"Error: Source folder '{source_folder}' not found.")
        return

    # List files and sort them to ensure consistent processing order
    files = sorted(list(source_path.iterdir()))

    # Determine the base directory for batch folders
    # If output_directory is None, use the current working directory (non-persistent in Colab)
    # Otherwise, use the specified output_directory
    base_output_path = Path(output_directory) if output_directory else Path(".")

    # Calculate the starting index in the files list
    start_index = (start_batch_num - 1) * batch_size

    # Check if the starting index is valid
    if start_index >= len(files):
        print(f"Error: Starting batch number {start_batch_num} is too high. No files remaining to process.")
        return

    print(f"Starting file splitting from index {start_index} (corresponding to batch {start_batch_num}).")

    for i in range(start_index, len(files), batch_size):
        # Calculate the current batch number based on the starting batch number
        current_batch_num = start_batch_num + (i - start_index) // batch_size
        batch_folder_name = f"batch_{current_batch_num:02d}"
        batch_folder_path = base_output_path / batch_folder_name

        # Use exist_ok=True and parents=True to create the directory and any necessary parent directories
        batch_folder_path.mkdir(exist_ok=True, parents=True)

        batch = files[i:i + batch_size]
        print(f"Processing batch {current_batch_num} with {len(batch)} files.")

        for file in batch:
            # Construct the full source and destination paths
            source_file_path = source_path / file.name
            destination_file_path = batch_folder_path / file.name

            # Ensure the source file still exists before attempting to move (in case of previous partial run)
            if source_file_path.exists():
                try:
                    shutil.move(str(source_file_path), str(destination_file_path))
                except FileExistsError:
                    print(f"Warning: File '{file.name}' already exists in '{batch_folder_path}'. Skipping move.")
                except Exception as e:
                    print(f"Error moving file '{file.name}': {e}")
            else:
                print(f"Warning: Source file '{file.name}' not found. Skipping.")


# Usage: Split files from the source folder into batch folders within the same source folder, starting from batch_01
source_folder_path = "/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_05/folder_2"
split_files(source_folder_path, batch_size=500, output_directory=source_folder_path, start_batch_num=1)
# Out:
# Starting file splitting from index 0 (corresponding to batch 1).
# Processing batch 1 with 500 files.
# Processing batch 2 with 500 files.
# Processing batch 3 with 500 files.
# Processing batch 4 with 500 files.
# Processing batch 5 with 500 files.
# Processing batch 6 with 500 files.
# Processing batch 7 with 500 files.
# Processing batch 8 with 500 files.
# Processing batch 9 with 500 files.
# Processing batch 10 with 500 files.

# %% [markdown]
# /content/batch_01

# %%
import os

folder_path = "/content/drive/MyDrive/IontheFold/downloads/70-80K/"
if os.path.exists(folder_path):
    files_in_folder = os.listdir(folder_path)
    if files_in_folder:
        print(f"Files in {folder_path}:")
        for file_name in files_in_folder:
            print(file_name)
    else:
        print(f"The folder {folder_path} is empty.")
else:
    print(f"The folder {folder_path} does not exist.")
# Out:
# Streaming output truncated to the last 5000 lines.
# 6BPA.pdb.gz
# 6BPA-sf.cif.gz
# 6BPB.cif.gz
# 6BPB.pdb.gz
# 6BPB-sf.cif.gz
# 6BPC.cif.gz
# 6BPC.pdb.gz
# 6BPC-sf.cif.gz
# 6BPD.cif.gz
# 6BPD.pdb.gz
# 6BPD-sf.cif.gz
# 6BR8.cif.gz
# 6BR8.pdb.gz
# 6BR8-sf.cif.gz
# 6BR9.cif.gz
# 6BR9.pdb.gz
# 6BR9-sf.cif.gz
# 6BRS.cif.gz
# 6BRS.pdb.gz
# 6BRS-sf.cif.gz
# 6BWO.cif.gz
# 6BWO.pdb.gz
# 6BWO-sf.cif.gz
# 6BWQ.cif.gz
# 6BWQ.pdb.gz
# 6BWQ-sf.cif.gz
# 6BWR.cif.gz
# 6BWR.pdb.gz
# 6BWR-sf.cif.gz
# 6BZU.cif.gz
# 6BZU.pdb.gz
# 6BZU-sf.cif.gz
# 6BZV.cif.gz
# 6BZV.pdb.gz
# 6BZV-sf.cif.gz
# 6BZW.cif.gz
# 6BZW.pdb.gz
# 6BZW-sf.cif.gz
# 6BZY.cif.gz
# 6BZY.pdb.gz
# 6BZY-sf.cif.gz
# 6C80.cif.gz
# 6C80.pdb.gz
# 6C80-sf.cif.gz
# 6C93.cif.gz
# 6C93.pdb.gz
# 6C93-sf.cif.gz
# 6DGB-sf.cif.gz
# 6DGC.cif.gz
# 6DGC.pdb.gz
# 6DGC-sf.cif.gz
# 6DKU.cif.gz
# 6DKU.pdb.gz
# 6DKU-sf.cif.gz
# 6DNE.cif.gz
# 6DNE.pdb.gz
# 6DNE-sf.cif.gz
# 6DRW.cif.gz
# 6DRW.pdb.gz
# 6DRW-sf.cif.gz
# 6DUS.cif.gz
# 6DUS.pdb.gz
# 6DUS-sf.cif.gz
# 6DVV.cif.gz
# 6DVV.pdb.gz
# 6DVV-sf.cif.gz
# 6DXH.cif.gz
# 6DXH.pdb.gz
# 6DXH-sf.cif.gz
# 6DZS.cif.gz
# 6DZS.pdb.gz
# 6DZS-sf.cif.gz
# 6EIK.cif.gz
# 6EIK.pdb.gz
# 6EIK-sf.cif.gz
# 6ETD.cif.gz
# 6ETD.pdb.gz
# 6ETD-sf.cif.gz
# 6ETF.cif.gz
# 6ETF.pdb.gz
# 6ETF-sf.cif.gz
# 6ETH.cif.gz
# 6ETH.pdb.gz
# 6ETH-sf.cif.gz
# 6EVH.cif.gz
# 6EVH.pdb.gz
# 6EVH-sf.cif.gz
# 6F1F.cif.gz
# 6F1F.pdb.gz
# 6F1F-sf.cif.gz
# 6FB0.cif.gz
# 6FB0.pdb.gz
# 6FB0-sf.cif.gz
# 6FB2.cif.gz
# 6FB2.pdb.gz
# 6FB2-sf.cif.gz
# 6FB5.cif.gz
# 6FB5.pdb.gz
# 6FB5-sf.cif.gz
# 6FB6.cif.gz
# 6FB6.pdb.gz
# 6FB6-sf.cif.gz
# 6FB7.cif.gz
# 6FB7.pdb.gz
# 6FB7-sf.cif.gz
# 6FB8.cif.gz
# 6FB8.pdb.gz
# 6FB8-sf.cif.gz
# 6FB9.cif.gz
# 6FB9.pdb.gz
# 6FB9-sf.cif.gz
# 6FEJ.cif.gz
# 6FEJ.pdb.gz
# 6FEJ-sf.cif.gz
# 6FOF.cif.gz
# 6FOF.pdb.gz
# 6FOF-sf.cif.gz
# 6FTD.cif.gz
# 6FTD.pdb.gz
# 6FTD-sf.cif.gz
# 6FWH.cif.gz
# 6FWH.pdb.gz
# 6FWH-sf.cif.gz
# 6FYI.cif.gz
# 6FYI.pdb.gz
# 6FYI-sf.cif.gz
# 6FYK.cif.gz
# 6FYK.pdb.gz
# 6FYK-sf.cif.gz
# 6FYL.cif.gz
# 6FYL.pdb.gz
# 6FYL-sf.cif.gz
# 6FYO.cif.gz
# 6FYO.pdb.gz
# 6FYO-sf.cif.gz
# 6FYP.cif.gz
# 6FYP.pdb.gz
# 6FYP-sf.cif.gz
# 6FYR.cif.gz
# 6FYR.pdb.gz
# 6FYR-sf.cif.gz
# 6FYV.cif.gz
# 6FYV.pdb.gz
# 6FYV-sf.cif.gz
# 6FZU.cif.gz
# 6FZU.pdb.gz
# 6FZU-sf.cif.gz
# 6G05.cif.gz
# 6G05.pdb.gz
# 6G05-sf.cif.gz
# 6G07.cif.gz
# 6G07.pdb.gz
# 6G07-sf.cif.gz
# 6GAX.cif.gz
# 6GAX.pdb.gz
# 6GAX-sf.cif.gz
# 6GAY.cif.gz
# 6GAY.pdb.gz
# 6GAY-sf.cif.gz
# 6GB0.cif.gz
# 6GB0.pdb.gz
# 6GB0-sf.cif.gz
# 6GB3.cif.gz
# 6GB3.pdb.gz
# 6GB3-sf.cif.gz
# 6GB4.cif.gz
# 6GB4.pdb.gz
# 6GB4-sf.cif.gz
# 6GB9.cif.gz
# 6GB9.pdb.gz
# 6GB9-sf.cif.gz
# 6GBA.cif.gz
# 6GBA.pdb.gz
# 6GBA-sf.cif.gz
# 6GBC.cif.gz
# 6GBC.pdb.gz
# 6GBC-sf.cif.gz
# 6GBF.cif.gz
# 6GBF.pdb.gz
# 6GBF-sf.cif.gz
# 6GBV.cif.gz
# 6GBV.pdb.gz
# 6GBV-sf.cif.gz
# 6GOA.cif.gz
# 6GOA.pdb.gz
# 6GOA-sf.cif.gz
# 6GPJ.cif.gz
# 6GPJ.pdb.gz
# 6GPJ-sf.cif.gz
# 6GPK.cif.gz
# 6GPK.pdb.gz
# 6GPK-sf.cif.gz
# 6GPL.cif.gz
# 6GPL.pdb.gz
# 6GPL-sf.cif.gz
# 6GQD.cif.gz
# 6GQD.pdb.gz
# 6GQD-sf.cif.gz
# 6GY4.cif.gz
# 6GY4.pdb.gz
# 6GY4-sf.cif.gz
# 6GZP.cif.gz
# 6GZP.pdb.gz
# 6GZP-sf.cif.gz
# 5NDX.cif.gz
# 5NDX.pdb.gz
# 5NDX-sf.cif.gz
# 5O9X.cif.gz
# 5O9X.pdb.gz
# 5O9X-sf.cif.gz
# 5OAW.cif.gz
# 5OAW.pdb.gz
# 5OAW-sf.cif.gz
# 5OW5.cif.gz
# 5OW5.pdb.gz
# 5OW5-sf.cif.gz
# 5OWO.cif.gz
# 5OWO.pdb.gz
# 5OWO-sf.cif.gz
# 5UTZ.cif.gz
# 5UTZ.pdb.gz
# 5UTZ-sf.cif.gz
# 5WCX.cif.gz
# 5WCX.pdb.gz
# 5WCX-sf.cif.gz
# 5WD6.cif.gz
# 5WD6.pdb.gz
# 5WD6-sf.cif.gz
# 5WDG.cif.gz
# 5WDG.pdb.gz
# 5WDG-sf.cif.gz
# 5WDK.cif.gz
# 5WDK.pdb.gz
# 5WDK-sf.cif.gz
# 5WDL.cif.gz
# 5WDL.pdb.gz
# 5WDL-sf.cif.gz
# 5WEC.cif.gz
# 5WEC.pdb.gz
# 5WEC-sf.cif.gz
# 5WEZ.cif.gz
# 5WEZ.pdb.gz
# 5WEZ-sf.cif.gz
# 5WXF.cif.gz
# 5WXF.pdb.gz
# 5WXF-sf.cif.gz
# 5WXO.cif.gz
# 5WXO.pdb.gz
# 5WXO-sf.cif.gz
# 5WXP.cif.gz
# 5WXP.pdb.gz
# 5WXP-sf.cif.gz
# 5WXQ.cif.gz
# 5WXQ.pdb.gz
# 5WXQ-sf.cif.gz
# 5WXR.cif.gz
# 5WXR.pdb.gz
# 5WXR-sf.cif.gz
# 5WXS.cif.gz
# 5WXS.pdb.gz
# 5WXS-sf.cif.gz
# 5WXT.cif.gz
# 5WXT.pdb.gz
# 5WXT-sf.cif.gz
# 5XET.cif.gz
# 5XET.pdb.gz
# 5XET-sf.cif.gz
# 5XGQ.cif.gz
# 5XGQ.pdb.gz
# 5XGQ-sf.cif.gz
# 5XLI.cif.gz
# 5XLI.pdb.gz
# 5XLI-sf.cif.gz
# 5XPN.cif.gz
# 5XPN.pdb.gz
# 5XPN-sf.cif.gz
# 5XWE.cif.gz
# 5XWE.pdb.gz
# 5XWE-sf.cif.gz
# 5XWR.cif.gz
# 5XWR.pdb.gz
# 5XWR-sf.cif.gz
# 5XX9.cif.gz
# 5XX9.pdb.gz
# 5XX9-sf.cif.gz
# 5XY9.cif.gz
# 5XY9.pdb.gz
# 5XY9-sf.cif.gz
# 5XYJ.cif.gz
# 5XYJ.pdb.gz
# 5XYJ-sf.cif.gz
# 5XYK.cif.gz
# 5XYK.pdb.gz
# 5XYK-sf.cif.gz
# 5XZ5.cif.gz
# 5XZ5.pdb.gz
# 5XZ5-sf.cif.gz
# 5Y82.cif.gz
# 5Y82.pdb.gz
# 5Y82-sf.cif.gz
# 5Y8G.cif.gz
# 5Y8G.pdb.gz
# 5Y8G-sf.cif.gz
# 5Y8H.cif.gz
# 5Y8H.pdb.gz
# 5Y8H-sf.cif.gz
# 5Y8I.cif.gz
# 5Y8I.pdb.gz
# 5Y8I-sf.cif.gz
# 5Y8J.cif.gz
# 5Y8J.pdb.gz
# 5Y8J-sf.cif.gz
# 5Y8K.cif.gz
# 5Y8K.pdb.gz
# 5Y8K-sf.cif.gz
# 5Y8L.cif.gz
# 5Y8L.pdb.gz
# 5Y8L-sf.cif.gz
# 5Y8M.cif.gz
# 5Y8M.pdb.gz
# 5Y8M-sf.cif.gz
# 5Y8N.cif.gz
# 5Y8N.pdb.gz
# 5Y8N-sf.cif.gz
# 5Y8O.cif.gz
# 5Y8O.pdb.gz
# 5Y8O-sf.cif.gz
# 5Y8P.cif.gz
# 5Y8P.pdb.gz
# 5Y8P-sf.cif.gz
# 5YA0.cif.gz
# 5YA0.pdb.gz
# 5YA0-sf.cif.gz
# 5YA1.cif.gz
# 5YA1.pdb.gz
# 5YA1-sf.cif.gz
# 5YA2.cif.gz
# 5YA2.pdb.gz
# 5YA2-sf.cif.gz
# 5YDN.cif.gz
# 5YDN.pdb.gz
# 5YDN-sf.cif.gz
# 5YIA.cif.gz
# 5YIA.pdb.gz
# 5YIA-sf.cif.gz
# 5YIB.cif.gz
# 5YIB.pdb.gz
# 5YIB-sf.cif.gz
# 5YIC.cif.gz
# 5YIC.pdb.gz
# 5YIC-sf.cif.gz
# 5YID.cif.gz
# 5YID.pdb.gz
# 5YID-sf.cif.gz
# 5YIE.cif.gz
# 5YIE.pdb.gz
# 5YIE-sf.cif.gz
# 5YOJ.cif.gz
# 5YOJ.pdb.gz
# 5YOJ-sf.cif.gz
# 5YT6.cif.gz
# 5YT6.pdb.gz
# 5YT6-sf.cif.gz
# 5ZL9.cif.gz
# 5ZL9.pdb.gz
# 5ZL9-sf.cif.gz
# 5ZV2.cif.gz
# 5ZV2.pdb.gz
# 5ZV2-sf.cif.gz
# 5ZW3.cif.gz
# 5ZW3.pdb.gz
# 5ZW3-sf.cif.gz
# 5ZW4.cif.gz
# 5ZW4.pdb.gz
# 5ZW4-sf.cif.gz
# 6A6D.cif.gz
# 6A6D.pdb.gz
# 6A6D-sf.cif.gz
# 6ATD.cif.gz
# 6ATD.pdb.gz
# 6ATD-sf.cif.gz
# 6AUQ.cif.gz
# 6AUQ.pdb.gz
# 6AUQ-sf.cif.gz
# 6AUR.cif.gz
# 6AUR.pdb.gz
# 6AUR-sf.cif.gz
# 6AUS.cif.gz
# 6AUS.pdb.gz
# 6AUS-sf.cif.gz
# 6AUT.cif.gz
# 6AUT.pdb.gz
# 6AUT-sf.cif.gz
# 6AUU.cif.gz
# 6AUU.pdb.gz
# 6AUU-sf.cif.gz
# 6AUV.cif.gz
# 6AUV.pdb.gz
# 6AUV-sf.cif.gz
# 6AUW.cif.gz
# 6AUW.pdb.gz
# 6AUW-sf.cif.gz
# 6AUX.cif.gz
# 6AUX.pdb.gz
# 6AUX-sf.cif.gz
# 6AUY.cif.gz
# 6AUY.pdb.gz
# 6AUY-sf.cif.gz
# 6AUZ.cif.gz
# 6AUZ.pdb.gz
# 6AUZ-sf.cif.gz
# 6AV0.cif.gz
# 6AV0.pdb.gz
# 6AV0-sf.cif.gz
# 6AV1.cif.gz
# 6AV1.pdb.gz
# 6AV1-sf.cif.gz
# 6AV2.cif.gz
# 6AV2.pdb.gz
# 6AV2-sf.cif.gz
# 6AV3.cif.gz
# 6AV3.pdb.gz
# 6AV3-sf.cif.gz
# 6AV4.cif.gz
# 6AV4.pdb.gz
# 6AV4-sf.cif.gz
# 6AV5.cif.gz
# 6AV5.pdb.gz
# 6AV5-sf.cif.gz
# 6AV6.cif.gz
# 6AV6.pdb.gz
# 6AV6-sf.cif.gz
# 6AV7.cif.gz
# 6AV7.pdb.gz
# 6AV7-sf.cif.gz
# 6BBA.cif.gz
# 6BBA.pdb.gz
# 6BBA-sf.cif.gz
# 6C71.cif.gz
# 6C71.pdb.gz
# 6C71-sf.cif.gz
# 6C9D.cif.gz
# 6C9D.pdb.gz
# 6C9D-sf.cif.gz
# 6CDA.cif.gz
# 6CDA.pdb.gz
# 6CDA-sf.cif.gz
# 6CDB.cif.gz
# 6CDB.pdb.gz
# 6CDB-sf.cif.gz
# 6CER.cif.gz
# 6CER.pdb.gz
# 6CER-sf.cif.gz
# 6CFO.cif.gz
# 6CFO.pdb.gz
# 6CFO-sf.cif.gz
# 6D42.cif.gz
# 6D42.pdb.gz
# 6D42-sf.cif.gz
# 6DB5.cif.gz
# 6DB5.pdb.gz
# 6DB5-sf.cif.gz
# 6DB6.cif.gz
# 6DB6.pdb.gz
# 6DB6-sf.cif.gz
# 6DB7.cif.gz
# 6DB7.pdb.gz
# 6DB7-sf.cif.gz
# 6DG4.cif.gz
# 6DG4.pdb.gz
# 6DG4-sf.cif.gz
# 6DKB.cif.gz
# 6DKB.pdb.gz
# 6DKB-sf.cif.gz
# 6DKG.cif.gz
# 6DKG.pdb.gz
# 6DKG-sf.cif.gz
# 6DKI.cif.gz
# 6DKI.pdb.gz
# 6DKI-sf.cif.gz
# 6DKW.cif.gz
# 6DKW.pdb.gz
# 6DKW-sf.cif.gz
# 6DRV.cif.gz
# 6DRV.pdb.gz
# 6DT7.cif.gz
# 6DT7.pdb.gz
# 6DT7-sf.cif.gz
# 6DTA.cif.gz
# 6DTA.pdb.gz
# 6DTA-sf.cif.gz
# 6DWE.cif.gz
# 6DWE.pdb.gz
# 6DWE-sf.cif.gz
# 6DXI.cif.gz
# 6DXI.pdb.gz
# 6DXI-sf.cif.gz
# 6DXN.cif.gz
# 6DXN.pdb.gz
# 6DXN-sf.cif.gz
# 6DXO.cif.gz
# 6DXO.pdb.gz
# 6DXO-sf.cif.gz
# 6EIZ.cif.gz
# 6EIZ.pdb.gz
# 6EIZ-sf.cif.gz
# 6EKE.cif.gz
# 6EKE.pdb.gz
# 6EKE-sf.cif.gz
# 6ELC.cif.gz
# 6ELC.pdb.gz
# 6ELC-sf.cif.gz
# 6EW2.cif.gz
# 6EW2.pdb.gz
# 6EW2-sf.cif.gz
# 6EW4.cif.gz
# 6EW4.pdb.gz
# 6EW4-sf.cif.gz
# 6EW5.cif.gz
# 6EW5.pdb.gz
# 6EW5-sf.cif.gz
# 6F5Z.cif.gz
# 6F5Z.pdb.gz
# 6F5Z-sf.cif.gz
# 6F8S.cif.gz
# 6F8S.pdb.gz
# 6F8S-sf.cif.gz
# 6FA5.cif.gz
# 6FA5.pdb.gz
# 6FA5-sf.cif.gz
# 6FA9.cif.gz
# 6FA9.pdb.gz
# 6FA9-sf.cif.gz
# 6FAA.cif.gz
# 6FAA.pdb.gz
# 6FAA-sf.cif.gz
# 6FAC.cif.gz
# 6FAC.pdb.gz
# 6FAC-sf.cif.gz
# 6FIG.cif.gz
# 6FIG.pdb.gz
# 6FIG-sf.cif.gz
# 6FIH.cif.gz
# 6FIH.pdb.gz
# 6FIH-sf.cif.gz
# 6FK0.cif.gz
# 6FK0.pdb.gz
# 6FK0-sf.cif.gz
# 6FMD.cif.gz
# 6FMD.pdb.gz
# 6FMD-sf.cif.gz
# 6FS6.cif.gz
# 6FS6.pdb.gz
# 6FS6-sf.cif.gz
# 6FS7.cif.gz
# 6FS7.pdb.gz
# 6FS7-sf.cif.gz
# 6FS8.cif.gz
# 6FS8.pdb.gz
# 6FS8-sf.cif.gz
# 6FS9.cif.gz
# 6FS9.pdb.gz
# 6FS9-sf.cif.gz
# 6FSB.cif.gz
# 6FSB.pdb.gz
# 6FSB-sf.cif.gz
# 6FSG.cif.gz
# 6FSG.pdb.gz
# 6FSG-sf.cif.gz
# 6FSI.cif.gz
# 6FSI.pdb.gz
# 6FSI-sf.cif.gz
# 6FT1.cif.gz
# 6FT1.pdb.gz
# 6FT1-sf.cif.gz
# 6FX1.cif.gz
# 6FX1.pdb.gz
# 6FX1-sf.cif.gz
# 6FX2.cif.gz
# 6FX2.pdb.gz
# 6FX2-sf.cif.gz
# 6FX3.cif.gz
# 6FX3.pdb.gz
# 6FX3-sf.cif.gz
# 6FX4.cif.gz
# 6FX4.pdb.gz
# 6FX4-sf.cif.gz
# 6FYH.cif.gz
# 6FYH.pdb.gz
# 6FYH-sf.cif.gz
# 6FZW.cif.gz
# 6FZW.pdb.gz
# 6FZW-sf.cif.gz
# 6G22.cif.gz
# 6G22.pdb.gz
# 6G22-sf.cif.gz
# 6G2L.cif.gz
# 6G2L.pdb.gz
# 6G2L-sf.cif.gz
# 6G2M.cif.gz
# 6G2M.pdb.gz
# 6G2M-sf.cif.gz
# 6G2N.cif.gz
# 6G2N.pdb.gz
# 6G2N-sf.cif.gz
# 6GFX.cif.gz
# 6GFX.pdb.gz
# 6GFX-sf.cif.gz
# 6GFY.cif.gz
# 6GFY.pdb.gz
# 6GFY-sf.cif.gz
# 6GFZ.cif.gz
# 6GFZ.pdb.gz
# 6GFZ-sf.cif.gz
# 6GNM.cif.gz
# 6GNM.pdb.gz
# 6GNM-sf.cif.gz
# 6GNO.cif.gz
# 6GNO.pdb.gz
# 6GNO-sf.cif.gz
# 6GNP.cif.gz
# 6GNP.pdb.gz
# 6GNP-sf.cif.gz
# 6GNR.cif.gz
# 6GNR.pdb.gz
# 6GNR-sf.cif.gz
# 6GNW.cif.gz
# 6GNW.pdb.gz
# 6GNW-sf.cif.gz
# 6GON.cif.gz
# 6GON.pdb.gz
# 6GON-sf.cif.gz
# 6GOO.cif.gz
# 6GOO.pdb.gz
# 6GOO-sf.cif.gz
# 6GR7.cif.gz
# 6GR7.pdb.gz
# 6GR7-sf.cif.gz
# 6GRP.cif.gz
# 6GRP.pdb.gz
# 6GRP-sf.cif.gz
# 6GVP.cif.gz
# 6GVP.pdb.gz
# 6GVP-sf.cif.gz
# 6GVR.cif.gz
# 6GVR.pdb.gz
# 6GVR-sf.cif.gz
# 5NCB.cif.gz
# 5NCB.pdb.gz
# 5NCB-sf.cif.gz
# 5NWE.cif.gz
# 5NWE.pdb.gz
# 5NWE-sf.cif.gz
# 5NZ4.cif.gz
# 5NZ4.pdb.gz
# 5NZ4-sf.cif.gz
# 5NZE.cif.gz
# 5NZE.pdb.gz
# 5NZE-sf.cif.gz
# 5NZF.cif.gz
# 5NZF.pdb.gz
# 5NZF-sf.cif.gz
# 5NZN.cif.gz
# 5NZN.pdb.gz
# 5NZN-sf.cif.gz
# 5OCK.cif.gz
# 5OCK.pdb.gz
# 5OCK-sf.cif.gz
# 5OCX.cif.gz
# 5OCX.pdb.gz
# 5OCX-sf.cif.gz
# 5OCY.cif.gz
# 5OCY.pdb.gz
# 5OCY-sf.cif.gz
# 5OD0.cif.gz
# 5OD0.pdb.gz
# 5OD0-sf.cif.gz
# 5OD3.cif.gz
# 5OD3.pdb.gz
# 5OD3-sf.cif.gz
# 5OD8.cif.gz
# 5OD8.pdb.gz
# 5OD8-sf.cif.gz
# 5ODB.cif.gz
# 5ODB.pdb.gz
# 5ODB-sf.cif.gz
# 5OGX.cif.gz
# 5OGX.pdb.gz
# 5OGX-sf.cif.gz
# 5OMR.cif.gz
# 5OMR.pdb.gz
# 5OMR-sf.cif.gz
# 5OMS.cif.gz
# 5OMS.pdb.gz
# 5OMS-sf.cif.gz
# 5OMU.cif.gz
# 5OMU.pdb.gz
# 5OMU-sf.cif.gz
# 5OTT.cif.gz
# 5OTT.pdb.gz
# 5OTT-sf.cif.gz
# 5OTU.cif.gz
# 5OTU.pdb.gz
# 5OTU-sf.cif.gz
# 5OTV.cif.gz
# 5OTV.pdb.gz
# 5OTV-sf.cif.gz
# 5OTW.cif.gz
# 5OTW.pdb.gz
# 5OTW-sf.cif.gz
# 5OTX.cif.gz
# 5OTX.pdb.gz
# 5OTX-sf.cif.gz
# 5UMP.cif.gz
# 5UMP.pdb.gz
# 5UMP-sf.cif.gz
# 5UMQ.cif.gz
# 5UMQ.pdb.gz
# 5UMQ-sf.cif.gz
# 5UMW.cif.gz
# 5UMW.pdb.gz
# 5UMW-sf.cif.gz
# 5UMX.cif.gz
# 5UMX.pdb.gz
# 5UMX-sf.cif.gz
# 5UMY.cif.gz
# 5UMY.pdb.gz
# 5UMY-sf.cif.gz
# 5W7R.cif.gz
# 5W7R.pdb.gz
# 5W7R-sf.cif.gz
# 5W87.cif.gz
# 5W87.pdb.gz
# 5W87-sf.cif.gz
# 5WA5.cif.gz
# 5WA5.pdb.gz
# 5WA5-sf.cif.gz
# 5WCH.cif.gz
# 5WCH.pdb.gz
# 5WCH-sf.cif.gz
# 5WCQ.cif.gz
# 5WCQ.pdb.gz
# 5WCQ-sf.cif.gz
# 5WJ8.cif.gz
# 5WJ8.pdb.gz
# 5WJ8-sf.cif.gz
# 5WJM.cif.gz
# 5WJM.pdb.gz
# 5WJM-sf.cif.gz
# 5WM9.cif.gz
# 5WM9.pdb.gz
# 5WM9-sf.cif.gz
# 5WQM.cif.gz
# 5WQM.pdb.gz
# 5WQM-sf.cif.gz
# 5X16.cif.gz
# 5X16.pdb.gz
# 5X16-sf.cif.gz
# 5XJT.cif.gz
# 5XJT.pdb.gz
# 5XJT-sf.cif.gz
# 5XJU.cif.gz
# 5XJU.pdb.gz
# 5XJU-sf.cif.gz
# 5XKE.cif.gz
# 5XKE.pdb.gz
# 5XKE-sf.cif.gz
# 5XOR.cif.gz
# 5XOR.pdb.gz
# 5XOR-sf.cif.gz
# 5XRB.cif.gz
# 5XRB.pdb.gz
# 5XRB-sf.cif.gz
# 5XRE.cif.gz
# 5XRE.pdb.gz
# 5XRE-sf.cif.gz
# 5XUX.cif.gz
# 5XUX.pdb.gz
# 5XUX-sf.cif.gz
# 5XUY.cif.gz
# 5XUY.pdb.gz
# 5XUY-sf.cif.gz
# 5XV0.cif.gz
# 5XV0.pdb.gz
# 5XV0-sf.cif.gz
# 5XV1.cif.gz
# 5XV1.pdb.gz
# 5XV1-sf.cif.gz
# 5XV2.cif.gz
# 5XV2.pdb.gz
# 5XV2-sf.cif.gz
# 5XV3.cif.gz
# 5XV3.pdb.gz
# 5XV3-sf.cif.gz
# 5XV4.cif.gz
# 5XV4.pdb.gz
# 5XV4-sf.cif.gz
# 5XV5.cif.gz
# 5XV5.pdb.gz
# 5XV5-sf.cif.gz
# 5XV6.cif.gz
# 5XV6.pdb.gz
# 5XV6-sf.cif.gz
# 5XVJ.cif.gz
# 5XVJ.pdb.gz
# 5XVJ-sf.cif.gz
# 5XVL.cif.gz
# 5XVL.pdb.gz
# 5XVL-sf.cif.gz
# 5XVW.cif.gz
# 5XVW.pdb.gz
# 5XVW-sf.cif.gz
# 5XVZ.cif.gz
# 5XVZ.pdb.gz
# 5XVZ-sf.cif.gz
# 5XW1.cif.gz
# 5XW1.pdb.gz
# 5XW1-sf.cif.gz
# 5XWF.cif.gz
# 5XWF.pdb.gz
# 5XWF-sf.cif.gz
# 5XWH.cif.gz
# 5XWH.pdb.gz
# 5XWH-sf.cif.gz
# 5XWI.cif.gz
# 5XWI.pdb.gz
# 5XWI-sf.cif.gz
# 5XX2.cif.gz
# 5XX2.pdb.gz
# 5XX2-sf.cif.gz
# 5XX3.cif.gz
# 5XX3.pdb.gz
# 5XX3-sf.cif.gz
# 5XX4.cif.gz
# 5XX4.pdb.gz
# 5XX4-sf.cif.gz
# 5XX5.cif.gz
# 5XX5.pdb.gz
# 5XX5-sf.cif.gz
# 5XX6.cif.gz
# 5XX6.pdb.gz
# 5XX6-sf.cif.gz
# 5XX7.cif.gz
# 5XX7.pdb.gz
# 5XX7-sf.cif.gz
# 5XX8.cif.gz
# 5XX8.pdb.gz
# 5XX8-sf.cif.gz
# 5Y33.cif.gz
# 5Y33.pdb.gz
# 5Y33-sf.cif.gz
# 5Y6M.cif.gz
# 5Y6M.pdb.gz
# 5Y6M-sf.cif.gz
# 5Y6N.cif.gz
# 5Y6N.pdb.gz
# 5Y6N-sf.cif.gz
# 5YA5.cif.gz
# 5YA5.pdb.gz
# 5YA5-sf.cif.gz
# 5YEQ.cif.gz
# 5YEQ.pdb.gz
# 5YEQ-sf.cif.gz
# 5YJB.cif.gz
# 5YJB.pdb.gz
# 5YJB-sf.cif.gz
# 5YPT.cif.gz
# 5YPT.pdb.gz
# 5YPT-sf.cif.gz
# 5YSM.cif.gz
# 5YSM.pdb.gz
# 5YSM-sf.cif.gz
# 5YSW.cif.gz
# 5YSW.pdb.gz
# 5YSW-sf.cif.gz
# 5YZH.cif.gz
# 5YZH.pdb.gz
# 5YZH-sf.cif.gz
# 5YZI.cif.gz
# 5YZI.pdb.gz
# 5YZI-sf.cif.gz
# 5Z12.cif.gz
# 5Z12.pdb.gz
# 5Z12-sf.cif.gz
# 5Z14.cif.gz
# 5Z14.pdb.gz
# 5Z14-sf.cif.gz
# 5Z15.cif.gz
# 5Z15.pdb.gz
# 5Z15-sf.cif.gz
# 5Z5A.cif.gz
# 5Z5A.pdb.gz
# 5Z5A-sf.cif.gz
# 5ZUE.cif.gz
# 5ZUE.pdb.gz
# 5ZUE-sf.cif.gz
# 6A4Y.cif.gz
# 6A4Y.pdb.gz
# 6A4Y-sf.cif.gz
# 6AQB.cif.gz
# 6AQB.pdb.gz
# 6AQB-sf.cif.gz
# 6AQR.cif.gz
# 6AQR.pdb.gz
# 6AQR-sf.cif.gz
# 6AR0.cif.gz
# 6AR0.pdb.gz
# 6AR0-sf.cif.gz
# 6AR2.cif.gz
# 6AR2.pdb.gz
# 6AR2-sf.cif.gz
# 6B86.cif.gz
# 6B86.pdb.gz
# 6B86-sf.cif.gz
# 6B9B.cif.gz
# 6B9B.pdb.gz
# 6B9B-sf.cif.gz
# 6BBX.cif.gz
# 6BBX.pdb.gz
# 6BBX-sf.cif.gz
# 6BIG.cif.gz
# 6BIG.pdb.gz
# 6BIG-sf.cif.gz
# 6BPS.cif.gz
# 6BPS.pdb.gz
# 6BPS-sf.cif.gz
# 6BPT.cif.gz
# 6BPT.pdb.gz
# 6BPT-sf.cif.gz
# 6BPU.cif.gz
# 6BPU.pdb.gz
# 6BPU-sf.cif.gz
# 6BPV.cif.gz
# 6BPV.pdb.gz
# 6BPV-sf.cif.gz
# 6BPW.cif.gz
# 6BPW.pdb.gz
# 6BPW-sf.cif.gz
# 6BPX.cif.gz
# 6BPX.pdb.gz
# 6BPX-sf.cif.gz
# 6BQC.cif.gz
# 6BQC.pdb.gz
# 6BQC-sf.cif.gz
# 6BTD.cif.gz
# 6BTD.pdb.gz
# 6BTD-sf.cif.gz
# 6BTG.cif.gz
# 6BTG.pdb.gz
# 6BTG-sf.cif.gz
# 6BVT.cif.gz
# 6BVT.pdb.gz
# 6BVT-sf.cif.gz
# 6BVV.cif.gz
# 6BVV.pdb.gz
# 6BVV-sf.cif.gz
# 6BVZ.cif.gz
# 6BVZ.pdb.gz
# 6BVZ-sf.cif.gz
# 6BW0.cif.gz
# 6BW0.pdb.gz
# 6BW0-sf.cif.gz
# 6BW1.cif.gz
# 6BW1.pdb.gz
# 6BW1-sf.cif.gz
# 6BW9.cif.gz
# 6BW9.pdb.gz
# 6BW9-sf.cif.gz
# 6BWA.cif.gz
# 6BWA.pdb.gz
# 6BWA-sf.cif.gz
# 6BWB.cif.gz
# 6BWB.pdb.gz
# 6BWB-sf.cif.gz
# 6BYN.cif.gz
# 6BYN.pdb.gz
# 6BYN-sf.cif.gz
# 6CBI.cif.gz
# 6CBI.pdb.gz
# 6CBI-sf.cif.gz
# 6CDD.cif.gz
# 6CDD.pdb.gz
# 6CDD-sf.cif.gz
# 6CDH.cif.gz
# 6CDH.pdb.gz
# 6CDH-sf.cif.gz
# 6CDN.cif.gz
# 6CDN.pdb.gz
# 6CDN-sf.cif.gz
# 6CJ7.cif.gz
# 6CJ7.pdb.gz
# 6CJ7-sf.cif.gz
# 6CR7.cif.gz
# 6CR7.pdb.gz
# 6CR7-sf.cif.gz
# 6CR8.cif.gz
# 6CR8.pdb.gz
# 6CR8-sf.cif.gz
# 6CR9.cif.gz
# 6CR9.pdb.gz
# 6CR9-sf.cif.gz
# 6CVP.cif.gz
# 6CVP.pdb.gz
# 6CVP-sf.cif.gz
# 6CVQ.cif.gz
# 6CVQ.pdb.gz
# 6CVQ-sf.cif.gz
# 6CVR.cif.gz
# 6CVR.pdb.gz
# 6CVR-sf.cif.gz
# 6CVS.cif.gz
# 6CVS.pdb.gz
# 6CVS-sf.cif.gz
# 6CVT.cif.gz
# 6CVT.pdb.gz
# 6CVT-sf.cif.gz
# 6D8O.cif.gz
# 6D8O.pdb.gz
# 6D8O-sf.cif.gz
# 6DAU.cif.gz
# 6DAU.pdb.gz
# 6DAU-sf.cif.gz
# 6DD3.cif.gz
# 6DD3.pdb.gz
# 6DD3-sf.cif.gz
# 6DDB.cif.gz
# 6DDB.pdb.gz
# 6DDB-sf.cif.gz
# 6DDC.cif.gz
# 6DDC.pdb.gz
# 6DDC-sf.cif.gz
# 6DDH.cif.gz
# 6DDH.pdb.gz
# 6DDH-sf.cif.gz
# 6DDK.cif.gz
# 6DDK.pdb.gz
# 6DDK-sf.cif.gz
# 6DDL.cif.gz
# 6DDL.pdb.gz
# 6DDL-sf.cif.gz
# 6DDO.cif.gz
# 6DDO.pdb.gz
# 6DDO-sf.cif.gz
# 6DDQ.cif.gz
# 6DDQ.pdb.gz
# 6DDQ-sf.cif.gz
# 6DDX.cif.gz
# 5YY3.pdb.gz
# 5YY3-sf.cif.gz
# 5YY5.cif.gz
# 5YY5.pdb.gz
# 5YY5-sf.cif.gz
# 5ZAI.cif.gz
# 5ZAI.pdb.gz
# 5ZAI-sf.cif.gz
# 5ZGM.cif.gz
# 5ZGM.pdb.gz
# 5ZGM-sf.cif.gz
# 5ZH6.cif.gz
# 5ZH6.pdb.gz
# 5ZH6-sf.cif.gz
# 5ZIB.cif.gz
# 5ZIB.pdb.gz
# 5ZIB-sf.cif.gz
# 5ZIC.cif.gz
# 5ZIC.pdb.gz
# 5ZIC-sf.cif.gz
# 5ZQC.cif.gz
# 5ZQC.pdb.gz
# 5ZQC-sf.cif.gz
# 5ZRT.cif.gz
# 5ZRT.pdb.gz
# 5ZRT-sf.cif.gz
# 5ZZN.cif.gz
# 5ZZN.pdb.gz
# 5ZZN-sf.cif.gz
# 6A8L.cif.gz
# 6A8L.pdb.gz
# 6A8L-sf.cif.gz
# 6AQ4.cif.gz
# 6AQ4.pdb.gz
# 6AQ4-sf.cif.gz
# 6ARB.cif.gz
# 6ARB.pdb.gz
# 6ARB-sf.cif.gz
# 6AS5.cif.gz
# 6AS5.pdb.gz
# 6AS5-sf.cif.gz
# 6B1F.cif.gz
# 6B1F.pdb.gz
# 6B1F-sf.cif.gz
# 6B1H.cif.gz
# 6B1H.pdb.gz
# 6B1H-sf.cif.gz
# 6B1J.cif.gz
# 6B1J.pdb.gz
# 6B1J-sf.cif.gz
# 6B1W.cif.gz
# 6B1W.pdb.gz
# 6B1W-sf.cif.gz
# 6B1X.cif.gz
# 6B1X.pdb.gz
# 6B1X-sf.cif.gz
# 6B1Y.cif.gz
# 6B1Y.pdb.gz
# 6B1Y-sf.cif.gz
# 6B22.cif.gz
# 6B22.pdb.gz
# 6B22-sf.cif.gz
# 6BA2.cif.gz
# 6BA2.pdb.gz
# 6BA2-sf.cif.gz
# 6BA4.cif.gz
# 6BA4.pdb.gz
# 6BA4-sf.cif.gz
# 6BC8.cif.gz
# 6BC8.pdb.gz
# 6BC8-sf.cif.gz
# 6BCD.cif.gz
# 6BCD.pdb.gz
# 6BCD-sf.cif.gz
# 6BE0.cif.gz
# 6BE0.pdb.gz
# 6BE0-sf.cif.gz
# 6BHS.cif.gz
# 6BHS.pdb.gz
# 6BHS-sf.cif.gz
# 6BHT.cif.gz
# 6BHT.pdb.gz
# 6BHT-sf.cif.gz
# 6BI7.cif.gz
# 6BI7.pdb.gz
# 6BI7-sf.cif.gz
# 6BVB.cif.gz
# 6BVB.pdb.gz
# 6BVB-sf.cif.gz
# 6BXB.cif.gz
# 6BXB.pdb.gz
# 6BXB-sf.cif.gz
# 6C0J.cif.gz
# 6C0J.pdb.gz
# 6C0J-sf.cif.gz
# 6C0K.cif.gz
# 6C0K.pdb.gz
# 6C0K-sf.cif.gz
# 6C0L.cif.gz
# 6C0L.pdb.gz
# 6C0L-sf.cif.gz
# 6C0N.cif.gz
# 6C0N.pdb.gz
# 6C0N-sf.cif.gz
# 6C0O.cif.gz
# 6C0O.pdb.gz
# 6C0O-sf.cif.gz
# 6C0P.cif.gz
# 6C0P.pdb.gz
# 6C0P-sf.cif.gz
# 6C0R.cif.gz
# 6C0R.pdb.gz
# 6C0R-sf.cif.gz
# 6C5Q.cif.gz
# 6C5Q.pdb.gz
# 6C5Q-sf.cif.gz
# 6C5T.cif.gz
# 6C5T.pdb.gz
# 6C5T-sf.cif.gz
# 6C7H.cif.gz
# 6C7H.pdb.gz
# 6C7H-sf.cif.gz
# 6C7M.cif.gz
# 6C7M.pdb.gz
# 6C7M-sf.cif.gz
# 6C7Q.cif.gz
# 6C7Q.pdb.gz
# 6C7Q-sf.cif.gz
# 6C7R.cif.gz
# 6C7R.pdb.gz
# 6C7R-sf.cif.gz
# 6C7T.cif.gz
# 6C7T.pdb.gz
# 6C7T-sf.cif.gz
# 6C7V.cif.gz
# 6C7V.pdb.gz
# 6C7V-sf.cif.gz
# 6C8B.cif.gz
# 6C8B.pdb.gz
# 6C8B-sf.cif.gz
# 6CAI.cif.gz
# 6CAI.pdb.gz
# 6CAI-sf.cif.gz
# 6CGF.cif.gz
# 6CGF.pdb.gz
# 6CGF-sf.cif.gz
# 6CHU.cif.gz
# 6CHU.pdb.gz
# 6CHU-sf.cif.gz
# 6CJ3.cif.gz
# 6CJ3.pdb.gz
# 6CJ3-sf.cif.gz
# 6CJ4.cif.gz
# 6CJ4.pdb.gz
# 6CJ4-sf.cif.gz
# 6CKB.cif.gz
# 6CKB.pdb.gz
# 6CKB-sf.cif.gz
# 6CP2.cif.gz
# 6CP2.pdb.gz
# 6CP2-sf.cif.gz
# 6CT2.cif.gz
# 6CT2.pdb.gz
# 6CT2-sf.cif.gz
# 6CT3.cif.gz
# 6CT3.pdb.gz
# 6CT3-sf.cif.gz
# 6CV7.cif.gz
# 6CV7.pdb.gz
# 6CV7-sf.cif.gz
# 6CYF.cif.gz
# 6CYF.pdb.gz
# 6CYF-sf.cif.gz
# 6CZQ.cif.gz
# 6CZQ.pdb.gz
# 6CZQ-sf.cif.gz
# 6DC1.cif.gz
# 6DC1.pdb.gz
# 6DC1-sf.cif.gz
# 6DD8.cif.gz
# 6DD8.pdb.gz
# 6DD8-sf.cif.gz
# 6DD9.cif.gz
# 6DD9.pdb.gz
# 6DD9-sf.cif.gz
# 6DEY.cif.gz
# 6DEY.pdb.gz
# 6DEY-sf.cif.gz
# 6DGT.cif.gz
# 6DGT.pdb.gz
# 6DGT-sf.cif.gz
# 6DK2.cif.gz
# 6DK2.pdb.gz
# 6DK2-sf.cif.gz
# 6DKV.cif.gz
# 6DKV.pdb.gz
# 6DKV-sf.cif.gz
# 6DM8.cif.gz
# 6DM8.pdb.gz
# 6DM8-sf.cif.gz
# 6DNJ.cif.gz
# 6DNJ.pdb.gz
# 6DNJ-sf.cif.gz
# 6DUF.cif.gz
# 6DUF.pdb.gz
# 6DUF-sf.cif.gz
# 6DUG.cif.gz
# 6DUG.pdb.gz
# 6DUG-sf.cif.gz
# 6DUH.cif.gz
# 6DUH.pdb.gz
# 6DUH-sf.cif.gz
# 6E5Y.cif.gz
# 6E5Y.pdb.gz
# 6E5Y-sf.cif.gz
# 6E5Z.cif.gz
# 6E5Z.pdb.gz
# 6E5Z-sf.cif.gz
# 6EYS.cif.gz
# 6EYS.pdb.gz
# 6EYS-sf.cif.gz
# 6EYV.cif.gz
# 6EYV.pdb.gz
# 6EYV-sf.cif.gz
# 6F2T.cif.gz
# 6F2T.pdb.gz
# 6F2T-sf.cif.gz
# 6F2V.cif.gz
# 6F2V.pdb.gz
# 6F2V-sf.cif.gz
# 6F2Y.cif.gz
# 6F2Y.pdb.gz
# 6F2Y-sf.cif.gz
# 6F30.cif.gz
# 6F30.pdb.gz
# 6F30-sf.cif.gz
# 6F45.cif.gz
# 6F45.pdb.gz
# 6F45-sf.cif.gz
# 6FDY.cif.gz
# 6FDY.pdb.gz
# 6FDY-sf.cif.gz
# 6FDZ.cif.gz
# 6FDZ.pdb.gz
# 6FDZ-sf.cif.gz
# 6FN0.cif.gz
# 6FN0.pdb.gz
# 6FN0-sf.cif.gz
# 6FN2.cif.gz
# 6FN2.pdb.gz
# 6FN2-sf.cif.gz
# 6FN3.cif.gz
# 6FN3.pdb.gz
# 6FN3-sf.cif.gz
# 6FWW.cif.gz
# 6FWW.pdb.gz
# 6FWW-sf.cif.gz
# 6G1O.cif.gz
# 6G1O.pdb.gz
# 6G1O-sf.cif.gz
# 6G3U.cif.gz
# 6G3U.pdb.gz
# 6G3U-sf.cif.gz
# 6G83.cif.gz
# 6G83.pdb.gz
# 6G83-sf.cif.gz
# 6G89.cif.gz
# 6G89.pdb.gz
# 6G89-sf.cif.gz
# 6G8A.cif.gz
# 6G8A.pdb.gz
# 6G8A-sf.cif.gz
# 6G8B.cif.gz
# 6G8B.pdb.gz
# 6G8B-sf.cif.gz
# 6GHP.cif.gz
# 6GHP.pdb.gz
# 6GHP-sf.cif.gz
# 6GOP.cif.gz
# 6GOP.pdb.gz
# 6GOP-sf.cif.gz
# 6GVV.cif.gz
# 6GVV.pdb.gz
# 6GVV-sf.cif.gz
# 6GVY.cif.gz
# 6GVY.pdb.gz
# 6GVY-sf.cif.gz
# 6H1U.cif.gz
# 6H1U.pdb.gz
# 6H1U-sf.cif.gz
# 6H20.cif.gz
# 6H20.pdb.gz
# 6H20-sf.cif.gz
# 5MXP.cif.gz
# 5MXP.pdb.gz
# 5MXP-sf.cif.gz
# 5OBA.cif.gz
# 5OBA.pdb.gz
# 5OBA-sf.cif.gz
# 5OBB.cif.gz
# 5OBB.pdb.gz
# 5OBB-sf.cif.gz
# 5OCC.cif.gz
# 5OCC.pdb.gz
# 5OCC-sf.cif.gz
# 5OWH.cif.gz
# 5OWH.pdb.gz
# 5OWH-sf.cif.gz
# 5OWL.cif.gz
# 5OWL.pdb.gz
# 5OWL-sf.cif.gz
# 5VO3.cif.gz
# 5VO3.pdb.gz
# 5VO3-sf.cif.gz
# 5WI9.cif.gz
# 5WI9.pdb.gz
# 5WI9-sf.cif.gz
# 5XEJ.cif.gz
# 5XEJ.pdb.gz
# 5XEJ-sf.cif.gz
# 5XRQ.cif.gz
# 5XRQ.pdb.gz
# 5XRQ-sf.cif.gz
# 5XRS.cif.gz
# 5XRS.pdb.gz
# 5XRS-sf.cif.gz
# 5XXA.cif.gz
# 5XXA.pdb.gz
# 5XXA-sf.cif.gz
# 5XZF.cif.gz
# 5XZF.pdb.gz
# 5XZF-sf.cif.gz
# 5XZH.cif.gz
# 5XZH.pdb.gz
# 5XZH-sf.cif.gz
# 5Y0L.cif.gz
# 5Y0L.pdb.gz
# 5Y0L-sf.cif.gz
# 5Y0M.cif.gz
# 5Y0M.pdb.gz
# 5Y0M-sf.cif.gz
# 5Y0Z.cif.gz
# 5Y0Z.pdb.gz
# 5Y0Z-sf.cif.gz
# 5Y17.cif.gz
# 5Y17.pdb.gz
# 5Y17-sf.cif.gz
# 5Y1A.cif.gz
# 5Y1A.pdb.gz
# 5Y1A-sf.cif.gz
# 5Y21.cif.gz
# 5Y21.pdb.gz
# 5Y21-sf.cif.gz
# 5Y23.cif.gz
# 5Y23.pdb.gz
# 5Y23-sf.cif.gz
# 5YE7.cif.gz
# 5YE7.pdb.gz
# 5YE7-sf.cif.gz
# 5YE8.cif.gz
# 5YE8.pdb.gz
# 5YE8-sf.cif.gz
# 5YE9.cif.gz
# 5YE9.pdb.gz
# 5YE9-sf.cif.gz
# 5YEA.cif.gz
# 5YEA.pdb.gz
# 5YEA-sf.cif.gz
# 5YGJ.cif.gz
# 5YGJ.pdb.gz
# 5YGJ-sf.cif.gz
# 5YGK.cif.gz
# 5YGK.pdb.gz
# 5YGK-sf.cif.gz
# 5YIN.cif.gz
# 5YIN.pdb.gz
# 5YIN-sf.cif.gz
# 5YJ9.cif.gz
# 5YJ9.pdb.gz
# 5YJ9-sf.cif.gz
# 5Z82.cif.gz
# 5Z82.pdb.gz
# 5Z82-sf.cif.gz
# 5Z89.cif.gz
# 5Z89.pdb.gz
# 5Z89-sf.cif.gz
# 5Z8L.cif.gz
# 5Z8L.pdb.gz
# 5Z8L-sf.cif.gz
# 5Z8P.cif.gz
# 5Z8P.pdb.gz
# 5Z8P-sf.cif.gz
# 5Z95.cif.gz
# 5Z95.pdb.gz
# 5Z95-sf.cif.gz
# 5ZB9.cif.gz
# 5ZB9.pdb.gz
# 5ZB9-sf.cif.gz
# 5ZCT.cif.gz
# 5ZCT.pdb.gz
# 5ZCT-sf.cif.gz
# 5ZDM.cif.gz
# 5ZDM.pdb.gz
# 5ZDM-sf.cif.gz
# 5ZDN.cif.gz
# 5ZDN.pdb.gz
# 5ZDN-sf.cif.gz
# 5ZM0.cif.gz
# 5ZM0.pdb.gz
# 5ZM0-sf.cif.gz
# 5ZQA.cif.gz
# 5ZQA.pdb.gz
# 5ZQA-sf.cif.gz
# 5ZQB.cif.gz
# 5ZQB.pdb.gz
# 5ZQB-sf.cif.gz
# 5ZQD.cif.gz
# 5ZQD.pdb.gz
# 5ZQD-sf.cif.gz
# 5ZQE.cif.gz
# 5ZQE.pdb.gz
# 5ZQE-sf.cif.gz
# 5ZWJ.cif.gz
# 5ZWJ.pdb.gz
# 5ZWJ-sf.cif.gz
# 5ZXD.cif.gz
# 5ZXD.pdb.gz
# 5ZXD-sf.cif.gz
# 6A56.cif.gz
# 6A56.pdb.gz
# 6A56-sf.cif.gz
# 6A89.cif.gz
# 6A89.pdb.gz
# 6A89-sf.cif.gz
# 6B4C.cif.gz
# 6B4C.pdb.gz
# 6B4C-sf.cif.gz
# 6B7U.cif.gz
# 6B7U.pdb.gz
# 6B7U-sf.cif.gz
# 6B7V.cif.gz
# 6B7V.pdb.gz
# 6B7V-sf.cif.gz
# 6B7W.cif.gz
# 6B7W.pdb.gz
# 6B7W-sf.cif.gz
# 6BJ3.cif.gz
# 6BJ3.pdb.gz
# 6BJ3-sf.cif.gz
# 6BJ8.cif.gz
# 6BJ8.pdb.gz
# 6BJ8-sf.cif.gz
# 6BJQ.cif.gz
# 6BJQ.pdb.gz
# 6BJQ-sf.cif.gz
# 6BKX.cif.gz
# 6BKX.pdb.gz
# 6BKX-sf.cif.gz
# 6BKY.cif.gz
# 6BKY.pdb.gz
# 6BKY-sf.cif.gz
# 6BKZ.cif.gz
# 6BKZ.pdb.gz
# 6BKZ-sf.cif.gz
# 6BL0.cif.gz
# 6BL0.pdb.gz
# 6BL0-sf.cif.gz
# 6BL1.cif.gz
# 6BL1.pdb.gz
# 6BL1-sf.cif.gz
# 6BL2.cif.gz
# 6BL2.pdb.gz
# 6BL2-sf.cif.gz
# 6BO6.cif.gz
# 6BO6.pdb.gz
# 6BO6-sf.cif.gz
# 6BOX.cif.gz
# 6BOX.pdb.gz
# 6BOX-sf.cif.gz
# 6BP4.cif.gz
# 6BP4.pdb.gz
# 6BP4-sf.cif.gz
# 6BTC.cif.gz
# 6BTC.pdb.gz
# 6BTC-sf.cif.gz
# 6C17.cif.gz
# 6C17.pdb.gz
# 6C17-sf.cif.gz
# 6C1J.cif.gz
# 6C1J.pdb.gz
# 6C1J-sf.cif.gz
# 6C1X.cif.gz
# 6C1X.pdb.gz
# 6C1X-sf.cif.gz
# 6CE2.cif.gz
# 6CE2.pdb.gz
# 6CE2-sf.cif.gz
# 6CRC.cif.gz
# 6CRC.pdb.gz
# 6CRC-sf.cif.gz
# 6CS9.cif.gz
# 6CS9.pdb.gz
# 6CS9-sf.cif.gz
# 6CUU.cif.gz
# 6CUU.pdb.gz
# 6CUU-sf.cif.gz
# 6D4O.cif.gz
# 6D4O.pdb.gz
# 6D4O-sf.cif.gz
# 6D8A.cif.gz
# 6D8A.pdb.gz
# 6D8A-sf.cif.gz
# 6D8F.cif.gz
# 6D8F.pdb.gz
# 6D8F-sf.cif.gz
# 6D8P.cif.gz
# 6D8P.pdb.gz
# 6D8P-sf.cif.gz
# 6D92.cif.gz
# 6D92.pdb.gz
# 6D92-sf.cif.gz
# 6D9K.cif.gz
# 6D9K.pdb.gz
# 6D9K-sf.cif.gz
# 6D9L.cif.gz
# 6D9L.pdb.gz
# 6D9L-sf.cif.gz
# 6DGE.cif.gz
# 6DGE.pdb.gz
# 6DGE-sf.cif.gz
# 6DHC.cif.gz
# 6DHC.pdb.gz
# 6DHC-sf.cif.gz
# 6DHD.cif.gz
# 6DHD.pdb.gz
# 6DHD-sf.cif.gz
# 6DHQ.cif.gz
# 6DHQ.pdb.gz
# 6DHQ-sf.cif.gz
# 6DHY.cif.gz
# 6DHY.pdb.gz
# 6DHY-sf.cif.gz
# 6DHZ.cif.gz
# 6DHZ.pdb.gz
# 6DHZ-sf.cif.gz
# 6DJC.cif.gz
# 6DJC.pdb.gz
# 6DJC-sf.cif.gz
# 6DUB.cif.gz
# 6DUB.pdb.gz
# 6DUB-sf.cif.gz
# 6DVR.cif.gz
# 6DVR.pdb.gz
# 6DVR-sf.cif.gz
# 6DXP.cif.gz
# 6DXP.pdb.gz
# 6DXP-sf.cif.gz
# 6E07.cif.gz
# 6E07.pdb.gz
# 6E07-sf.cif.gz
# 6E08.cif.gz
# 6E08.pdb.gz
# 6E08-sf.cif.gz
# 6E0S.cif.gz
# 6E0S.pdb.gz
# 6E0S-sf.cif.gz
# 6E12.cif.gz
# 6E12.pdb.gz
# 6E12-sf.cif.gz
# 6E29.cif.gz
# 6E29.pdb.gz
# 6E29-sf.cif.gz
# 6E35.cif.gz
# 6E35.pdb.gz
# 6E35-sf.cif.gz
# 6E4E.cif.gz
# 6E4E.pdb.gz
# 6E4E-sf.cif.gz
# 6EK3.cif.gz
# 6EK3.pdb.gz
# 6EK3-sf.cif.gz
# 6EP3.cif.gz
# 6EP3.pdb.gz
# 6EP3-sf.cif.gz
# 6F3Z.cif.gz
# 6F3Z.pdb.gz
# 6F3Z-sf.cif.gz
# 6F49.cif.gz
# 6F49.pdb.gz
# 6F49-sf.cif.gz
# 6FHE.cif.gz
# 6FHE.pdb.gz
# 6FHE-sf.cif.gz
# 6FHF.cif.gz
# 6FHF.pdb.gz
# 6FHF-sf.cif.gz
# 6FHM.cif.gz
# 6FHM.pdb.gz
# 6FHM-sf.cif.gz
# 6FJ7.cif.gz
# 6FJ7.pdb.gz
# 6FJ7-sf.cif.gz
# 6FJU.cif.gz
# 6FJU.pdb.gz
# 6FJU-sf.cif.gz
# 6FJV.cif.gz
# 6FJV.pdb.gz
# 6FJV-sf.cif.gz
# 6FNN.cif.gz
# 6FNN.pdb.gz
# 6FNN-sf.cif.gz
# 6FNO.cif.gz
# 6FNO.pdb.gz
# 6FNO-sf.cif.gz
# 6FQP.cif.gz
# 6FQP.pdb.gz
# 6FQP-sf.cif.gz
# 6FSA.cif.gz
# 6FSA.pdb.gz
# 6FSA-sf.cif.gz
# 6G1T.cif.gz
# 6G1T.pdb.gz
# 6G1T-sf.cif.gz
# 6GDR.cif.gz
# 6GDR.pdb.gz
# 6GDR-sf.cif.gz
# 6GG9.cif.gz
# 6GG9.pdb.gz
# 6GG9-sf.cif.gz
# 6GH8.cif.gz
# 6GH8.pdb.gz
# 6GH8-sf.cif.gz
# 6GJT.cif.gz
# 6GJT.pdb.gz
# 6GJT-sf.cif.gz
# 6GNE.cif.gz
# 6GNE.pdb.gz
# 6GNE-sf.cif.gz
# 6GNF.cif.gz
# 6GNF.pdb.gz
# 6GNF-sf.cif.gz
# 6GNG.cif.gz
# 6GNG.pdb.gz
# 6GNG-sf.cif.gz
# 6GOB.cif.gz
# 6GOB.pdb.gz
# 6GOB-sf.cif.gz
# 6GOH.cif.gz
# 6GOH.pdb.gz
# 6GOH-sf.cif.gz
# 6GOI.cif.gz
# 6GOI.pdb.gz
# 6GOI-sf.cif.gz
# 6GOJ.cif.gz
# 6GOJ.pdb.gz
# 6GOJ-sf.cif.gz
# 6GOK.cif.gz
# 6GOK.pdb.gz
# 6GOK-sf.cif.gz
# 6GW5.cif.gz
# 6GW5.pdb.gz
# 6GW5-sf.cif.gz
# 6GY8.cif.gz
# 6GY8.pdb.gz
# 6GY8-sf.cif.gz
# 6H06.cif.gz
# 6H06.pdb.gz
# 6H06-sf.cif.gz
# 6H0E.cif.gz
# 6H0E.pdb.gz
# 6H0E-sf.cif.gz
# 6H2T.cif.gz
# 6H2T.pdb.gz
# 6H2T-sf.cif.gz
# 5OWB.cif.gz
# 5OWB.pdb.gz
# 5OWB-sf.cif.gz
# 5QIB.cif.gz
# 5QIB.pdb.gz
# 5QIB-sf.cif.gz
# 5QIC.cif.gz
# 5QIC.pdb.gz
# 5QIC-sf.cif.gz
# 5QID.cif.gz
# 5QID.pdb.gz
# 5QID-sf.cif.gz
# 5QIE.cif.gz
# 5QIE.pdb.gz
# 5QIE-sf.cif.gz
# 5QIF.cif.gz
# 5QIF.pdb.gz
# 5QIF-sf.cif.gz
# 5QIG.cif.gz
# 5QIG.pdb.gz
# 5QIG-sf.cif.gz
# 5QIH.cif.gz
# 5QIH.pdb.gz
# 5QIH-sf.cif.gz
# 5VX4.cif.gz
# 5VX4.pdb.gz
# 5VX4-sf.cif.gz
# 5VX5.cif.gz
# 5VX5.pdb.gz
# 5VX5-sf.cif.gz
# 5VX8.cif.gz
# 5VX8.pdb.gz
# 5VX8-sf.cif.gz
# 5VX9.cif.gz
# 5VX9.pdb.gz
# 5VX9-sf.cif.gz
# 5W6K.cif.gz
# 5W6K.pdb.gz
# 5W6K-sf.cif.gz
# 5W6Q.cif.gz
# 5W6Q.pdb.gz
# 5W6Q-sf.cif.gz
# 5WFU.cif.gz
# 5WFU.pdb.gz
# 5WFU-sf.cif.gz
# 5WG8.cif.gz
# 5WG8.pdb.gz
# 5WG8-sf.cif.gz
# 5WH5.cif.gz
# 5WH5.pdb.gz
# 5WH5-sf.cif.gz
# 5WH6.cif.gz
# 5WH6.pdb.gz
# 5WH6-sf.cif.gz
# 5WJA.cif.gz
# 5WJA.pdb.gz
# 5WJA-sf.cif.gz
# 5WKW.cif.gz
# 5WKW.pdb.gz
# 5WKW-sf.cif.gz
# 5WM0.cif.gz
# 5WM0.pdb.gz
# 5WM0-sf.cif.gz
# 5XWK.cif.gz
# 5XWK.pdb.gz
# 5XWK-sf.cif.gz
# 5XY4.cif.gz
# 5XY4.pdb.gz
# 5XY4-sf.cif.gz
# 5XZ2.cif.gz
# 5XZ2.pdb.gz
# 5XZ2-sf.cif.gz
# 5XZ3.cif.gz
# 5XZ3.pdb.gz
# 5XZ3-sf.cif.gz
# 5XZD.cif.gz
# 5XZD.pdb.gz
# 5XZD-sf.cif.gz
# 5XZM.cif.gz
# 5XZM.pdb.gz
# 5XZM-sf.cif.gz
# 5XZN.cif.gz
# 5XZN.pdb.gz
# 5XZN-sf.cif.gz
# 5Y0C.cif.gz
# 5Y0C.pdb.gz
# 5Y0C-sf.cif.gz
# 5Y0D.cif.gz
# 5Y0D.pdb.gz
# 5Y0D-sf.cif.gz
# 5Y0N.cif.gz
# 5Y0N.pdb.gz
# 5Y0N-sf.cif.gz
# 5Y0O.cif.gz
# 5Y0O.pdb.gz
# 5Y0O-sf.cif.gz
# 5Y0P.cif.gz
# 5Y0P.pdb.gz
# 5Y0P-sf.cif.gz
# 5Y0Q.cif.gz
# 5Y0Q.pdb.gz
# 5Y0Q-sf.cif.gz
# 5Y0S.cif.gz
# 5Y0S.pdb.gz
# 5Y0S-sf.cif.gz
# 5Y0T.cif.gz
# 5Y0T.pdb.gz
# 5Y0T-sf.cif.gz
# 5Y4G.cif.gz
# 5Y4G.pdb.gz
# 5Y4G-sf.cif.gz
# 5Y6B.cif.gz
# 5Y6B.pdb.gz
# 5Y6B-sf.cif.gz
# 5Y6C.cif.gz
# 5Y6C.pdb.gz
# 5Y6C-sf.cif.gz
# 5Y6F.cif.gz
# 5Y6F.pdb.gz
# 5Y6F-sf.cif.gz
# 5Y6G.cif.gz
# 5Y6G.pdb.gz
# 5Y6G-sf.cif.gz
# 5Y6H.cif.gz
# 5Y6H.pdb.gz
# 5Y6H-sf.cif.gz
# 5Y72.cif.gz
# 5Y72.pdb.gz
# 5Y72-sf.cif.gz
# 5Y7C.cif.gz
# 5Y7C.pdb.gz
# 5Y7C-sf.cif.gz
# 5Y84.cif.gz
# 5Y84.pdb.gz
# 5Y84-sf.cif.gz
# 5YB9.cif.gz
# 5YB9.pdb.gz
# 5YB9-sf.cif.gz
# 5YBA.cif.gz
# 5YBA.pdb.gz
# 5YBA-sf.cif.gz
# 5YEM.cif.gz
# 5YEM.pdb.gz
# 5YEM-sf.cif.gz
# 5YOK.cif.gz
# 5YOK.pdb.gz
# 5YOK-sf.cif.gz
# 5YV5.cif.gz
# 5YV5.pdb.gz
# 5YV5-sf.cif.gz
# 5YY4.cif.gz
# 5YY4.pdb.gz
# 5YY4-sf.cif.gz
# 5Z30.cif.gz
# 5Z30.pdb.gz
# 5Z30-sf.cif.gz
# 5ZE4.cif.gz
# 5ZE4.pdb.gz
# 5ZE4-sf.cif.gz
# 5ZM2.cif.gz
# 5ZM2.pdb.gz
# 5ZM2-sf.cif.gz
# 5ZM3.cif.gz
# 5ZM3.pdb.gz
# 5ZM3-sf.cif.gz
# 5ZM4.cif.gz
# 5ZM4.pdb.gz
# 5ZM4-sf.cif.gz
# 5ZNN.cif.gz
# 5ZNN.pdb.gz
# 5ZNN-sf.cif.gz
# 5ZNP.cif.gz
# 5ZNP.pdb.gz
# 5ZNP-sf.cif.gz
# 5ZTN.cif.gz
# 5ZTN.pdb.gz
# 5ZTN-sf.cif.gz
# 5ZWE.cif.gz
# 5ZWE.pdb.gz
# 5ZWE-sf.cif.gz
# 5ZWF.cif.gz
# 5ZWF.pdb.gz
# 5ZWF-sf.cif.gz
# 5ZWH.cif.gz
# 5ZWH.pdb.gz
# 5ZWH-sf.cif.gz
# 5ZWI.cif.gz
# 5ZWI.pdb.gz
# 5ZWI-sf.cif.gz
# 6A4I.cif.gz
# 6A4I.pdb.gz
# 6A4I-sf.cif.gz
# 6A6Y.cif.gz
# 6A6Y.pdb.gz
# 6A6Y-sf.cif.gz
# 6A75.cif.gz
# 6A75.pdb.gz
# 6A75-sf.cif.gz
# 6A7D.cif.gz
# 6A7D.pdb.gz
# 6A7D-sf.cif.gz
# 6ALA.cif.gz
# 6ALA.pdb.gz
# 6ALA-sf.cif.gz
# 6AMP.cif.gz
# 6AMP.pdb.gz
# 6AMP-sf.cif.gz
# 6AN3.cif.gz
# 6AN3.pdb.gz
# 6AN3-sf.cif.gz
# 6AO6.cif.gz
# 6AO6.pdb.gz
# 6AO6-sf.cif.gz
# 6AY0.cif.gz
# 6AY0.pdb.gz
# 6AY0-sf.cif.gz
# 6BEB.cif.gz
# 6BEB.pdb.gz
# 6BEB-sf.cif.gz
# 6BEC.cif.gz
# 6BEC.pdb.gz
# 6BEC-sf.cif.gz
# 6BED.cif.gz
# 6BED.pdb.gz
# 6BED-sf.cif.gz
# 6BEI.cif.gz
# 6BEI.pdb.gz
# 6BEI-sf.cif.gz
# 6BGA.cif.gz
# 6BGA.pdb.gz
# 6BGA-sf.cif.gz
# 6BKG.cif.gz
# 6BKG.pdb.gz
# 6BKG-sf.cif.gz
# 6BRA.cif.gz
# 6BRA.pdb.gz
# 6BRA-sf.cif.gz
# 6BUX.cif.gz
# 6BUX.pdb.gz
# 6BUX-sf.cif.gz
# 6BVA.cif.gz
# 6BVA.pdb.gz
# 6BVA-sf.cif.gz
# 6BYC.cif.gz
# 6BYC.pdb.gz
# 6BYC-sf.cif.gz
# 6BYE.cif.gz
# 6BYE.pdb.gz
# 6BYE-sf.cif.gz
# 6BYG.cif.gz
# 6BYG.pdb.gz
# 6BYG-sf.cif.gz
# 6BYH.cif.gz
# 6BYH.pdb.gz
# 6BYH-sf.cif.gz
# 6BYI.cif.gz
# 6BYI.pdb.gz
# 6BYI-sf.cif.gz
# 6CDS.cif.gz
# 6CDS.pdb.gz
# 6CDS-sf.cif.gz
# 6CDW.cif.gz
# 6CDW.pdb.gz
# 6CDW-sf.cif.gz
# 6CGJ.cif.gz
# 6CGJ.pdb.gz
# 6CGJ-sf.cif.gz
# 6CGK.cif.gz
# 6CGK.pdb.gz
# 6CGK-sf.cif.gz
# 6CR4.cif.gz
# 6CR4.pdb.gz
# 6CR4-sf.cif.gz
# 6CR5.cif.gz
# 6CR5.pdb.gz
# 6CR5-sf.cif.gz
# 6CRB.cif.gz
# 6CRB.pdb.gz
# 6CRB-sf.cif.gz
# 6CT9.cif.gz
# 6CT9.pdb.gz
# 6CT9-sf.cif.gz
# 6CTA.cif.gz
# 6CTA.pdb.gz
# 6CTA-sf.cif.gz
# 6D21.cif.gz
# 6D21.pdb.gz
# 6D21-sf.cif.gz
# 6D2K.cif.gz
# 6D2K.pdb.gz
# 6D2K-sf.cif.gz
# 6D2Q.cif.gz
# 6D2Q.pdb.gz
# 6D2Q-sf.cif.gz
# 6D8E.cif.gz
# 6D8E.pdb.gz
# 6D8E-sf.cif.gz
# 6DAS.cif.gz
# 6DAS.pdb.gz
# 6DAS-sf.cif.gz
# 6DBA.cif.gz
# 6DBA.pdb.gz
# 6DBA-sf.cif.gz
# 6DBD.cif.gz
# 6DBD.pdb.gz
# 6DBD-sf.cif.gz
# 6DBE.cif.gz
# 6DBE.pdb.gz
# 6DBE-sf.cif.gz
# 6DBF.cif.gz
# 6DBF.pdb.gz
# 6DBF-sf.cif.gz
# 6DBG.cif.gz
# 6DBG.pdb.gz
# 6DBG-sf.cif.gz
# 6DCS.cif.gz
# 6DCS.pdb.gz
# 6DCS-sf.cif.gz
# 6DD6.cif.gz
# 6DD6.pdb.gz
# 6DD6-sf.cif.gz
# 6DD7.cif.gz
# 6DD7.pdb.gz
# 6DD7-sf.cif.gz
# 6DGB.cif.gz
# 6DGB.pdb.gz
# 5Q74.pdb.gz
# 5Q74-sf.cif.gz
# 5Q75.cif.gz
# 5Q75.pdb.gz
# 5Q75-sf.cif.gz
# 5Q76.cif.gz
# 5Q76.pdb.gz
# 5Q76-sf.cif.gz
# 5Q77.cif.gz
# 5Q77.pdb.gz
# 5Q77-sf.cif.gz
# 5Q78.cif.gz
# 5Q78.pdb.gz
# 5Q78-sf.cif.gz
# 5Q79.cif.gz
# 5Q79.pdb.gz
# 5Q79-sf.cif.gz
# 5Q7A.cif.gz
# 5Q7A.pdb.gz
# 5Q7A-sf.cif.gz
# 5Q7B.cif.gz
# 5Q7B.pdb.gz
# 5Q7B-sf.cif.gz
# 5Q7C.cif.gz
# 5Q7C.pdb.gz
# 5Q7C-sf.cif.gz
# 5Q7D.cif.gz
# 5Q7D.pdb.gz
# 5Q7D-sf.cif.gz
# 5Q7E.cif.gz
# 5Q7E.pdb.gz
# 5Q7E-sf.cif.gz
# 5Q7F.cif.gz
# 5Q7F.pdb.gz
# 5Q7F-sf.cif.gz
# 5Q7G.cif.gz
# 5Q7G.pdb.gz
# 5Q7G-sf.cif.gz
# 5Q7H.cif.gz
# 5Q7H.pdb.gz
# 5Q7H-sf.cif.gz
# 5Q7I.cif.gz
# 5Q7I.pdb.gz
# 5Q7I-sf.cif.gz
# 5Q7J.cif.gz
# 5Q7J.pdb.gz
# 5Q7J-sf.cif.gz
# 5Q7K.cif.gz
# 5Q7K.pdb.gz
# 5Q7K-sf.cif.gz
# 5Q7L.cif.gz
# 5Q7L.pdb.gz
# 5Q7L-sf.cif.gz
# 5Q7M.cif.gz
# 5Q7M.pdb.gz
# 5Q7M-sf.cif.gz
# 5Q7N.cif.gz
# 5Q7N.pdb.gz
# 5Q7N-sf.cif.gz
# 5Q7O.cif.gz
# 5Q7O.pdb.gz
# 5Q7O-sf.cif.gz
# 5Q7P.cif.gz
# 5Q7P.pdb.gz
# 5Q7P-sf.cif.gz
# 5Q7Q.cif.gz
# 5Q7Q.pdb.gz
# 5Q7Q-sf.cif.gz
# 5Q7R.cif.gz
# 5Q7R.pdb.gz
# 5Q7R-sf.cif.gz
# 5Q7S.cif.gz
# 5Q7S.pdb.gz
# 5Q7S-sf.cif.gz
# 5Q7T.cif.gz
# 5Q7T.pdb.gz
# 5Q7T-sf.cif.gz
# 5Q7U.cif.gz
# 5Q7U.pdb.gz
# 5Q7U-sf.cif.gz
# 5Q7V.cif.gz
# 5Q7V.pdb.gz
# 5Q7V-sf.cif.gz
# 5Q7W.cif.gz
# 5Q7W.pdb.gz
# 5Q7W-sf.cif.gz
# 5Q7X.cif.gz
# 5Q7X.pdb.gz
# 5Q7X-sf.cif.gz
# 5Q7Y.cif.gz
# 5Q7Y.pdb.gz
# 5Q7Y-sf.cif.gz
# 5Q7Z.cif.gz
# 5Q7Z.pdb.gz
# 5Q7Z-sf.cif.gz
# 5Q80.cif.gz
# 5Q80.pdb.gz
# 5Q80-sf.cif.gz
# 5Q81.cif.gz
# 5Q81.pdb.gz
# 5Q81-sf.cif.gz
# 5Q82.cif.gz
# 5Q82.pdb.gz
# 5Q82-sf.cif.gz
# 5Q83.cif.gz
# 5Q83.pdb.gz
# 5Q83-sf.cif.gz
# 5Q84.cif.gz
# 5Q84.pdb.gz
# 5Q84-sf.cif.gz
# 5Q85.cif.gz
# 5Q85.pdb.gz
# 5Q85-sf.cif.gz
# 5Q86.cif.gz
# 5Q86.pdb.gz
# 5Q86-sf.cif.gz
# 5Q87.cif.gz
# 5Q87.pdb.gz
# 5Q87-sf.cif.gz
# 5Q88.cif.gz
# 5Q88.pdb.gz
# 5Q88-sf.cif.gz
# 5Q89.cif.gz
# 5Q89.pdb.gz
# 5Q89-sf.cif.gz
# 5Q8A.cif.gz
# 5Q8A.pdb.gz
# 5Q8A-sf.cif.gz
# 5Q8B.cif.gz
# 5Q8B.pdb.gz
# 5Q8B-sf.cif.gz
# 5Q8C.cif.gz
# 5Q8C.pdb.gz
# 5Q8C-sf.cif.gz
# 5Q8D.cif.gz
# 5Q8D.pdb.gz
# 5Q8D-sf.cif.gz
# 5Q8E.cif.gz
# 5Q8E.pdb.gz
# 5Q8E-sf.cif.gz
# 5Q8F.cif.gz
# 5Q8F.pdb.gz
# 5Q8F-sf.cif.gz
# 5Q8G.cif.gz
# 5Q8G.pdb.gz
# 5Q8G-sf.cif.gz
# 5Q8H.cif.gz
# 5Q8H.pdb.gz
# 5Q8H-sf.cif.gz
# 5Q8I.cif.gz
# 5Q8I.pdb.gz
# 5Q8I-sf.cif.gz
# 5Q8J.cif.gz
# 5Q8J.pdb.gz
# 5Q8J-sf.cif.gz
# 5Q8K.cif.gz
# 5Q8K.pdb.gz
# 5Q8K-sf.cif.gz
# 5Q8L.cif.gz
# 5Q8L.pdb.gz
# 5Q8L-sf.cif.gz
# 5Q8M.cif.gz
# 5Q8M.pdb.gz
# 5Q8M-sf.cif.gz
# 5Q8N.cif.gz
# 5Q8N.pdb.gz
# 5Q8N-sf.cif.gz
# 5Q8O.cif.gz
# 5Q8O.pdb.gz
# 5Q8O-sf.cif.gz
# 5Q8P.cif.gz
# 5Q8P.pdb.gz
# 5Q8P-sf.cif.gz
# 5Q8Q.cif.gz
# 5Q8Q.pdb.gz
# 5Q8Q-sf.cif.gz
# 5Q8R.cif.gz
# 5Q8R.pdb.gz
# 5Q8R-sf.cif.gz
# 5Q8S.cif.gz
# 5Q8S.pdb.gz
# 5Q8S-sf.cif.gz
# 5Q8T.cif.gz
# 5Q8T.pdb.gz
# 5Q8T-sf.cif.gz
# 5Q8U.cif.gz
# 5Q8U.pdb.gz
# 5Q8U-sf.cif.gz
# 5Q8V.cif.gz
# 5Q8V.pdb.gz
# 5Q8V-sf.cif.gz
# 5Q8W.cif.gz
# 5Q8W.pdb.gz
# 5Q8W-sf.cif.gz
# 5Q8X.cif.gz
# 5Q8X.pdb.gz
# 5Q8X-sf.cif.gz
# 5Q8Y.cif.gz
# 5Q8Y.pdb.gz
# 5Q8Y-sf.cif.gz
# 5Q8Z.cif.gz
# 5Q8Z.pdb.gz
# 5Q8Z-sf.cif.gz
# 5Q90.cif.gz
# 5Q90.pdb.gz
# 5Q90-sf.cif.gz
# 5Q91.cif.gz
# 5Q91.pdb.gz
# 5Q91-sf.cif.gz
# 5Q92.cif.gz
# 5Q92.pdb.gz
# 5Q92-sf.cif.gz
# 5Q93.cif.gz
# 5Q93.pdb.gz
# 5Q93-sf.cif.gz
# 5Q94.cif.gz
# 5Q94.pdb.gz
# 5Q94-sf.cif.gz
# 5Q95.cif.gz
# 5Q95.pdb.gz
# 5Q95-sf.cif.gz
# 5Q96.cif.gz
# 5Q96.pdb.gz
# 5Q96-sf.cif.gz
# 5Q97.cif.gz
# 5Q97.pdb.gz
# 5Q97-sf.cif.gz
# 5Q98.cif.gz
# 5Q98.pdb.gz
# 5Q98-sf.cif.gz
# 5Q99.cif.gz
# 5Q99.pdb.gz
# 5Q99-sf.cif.gz
# 5Q9A.cif.gz
# 5Q9A.pdb.gz
# 5Q9A-sf.cif.gz
# 5Q9B.cif.gz
# 5Q9B.pdb.gz
# 5Q9B-sf.cif.gz
# 5Q9C.cif.gz
# 5Q9C.pdb.gz
# 5Q9C-sf.cif.gz
# 5Q9D.cif.gz
# 5Q9D.pdb.gz
# 5Q9D-sf.cif.gz
# 5Q9E.cif.gz
# 5Q9E.pdb.gz
# 5Q9E-sf.cif.gz
# 5Q9F.cif.gz
# 5Q9F.pdb.gz
# 5Q9F-sf.cif.gz
# 5Q9G.cif.gz
# 5Q9G.pdb.gz
# 5Q9G-sf.cif.gz
# 5Q9H.cif.gz
# 5Q9H.pdb.gz
# 5Q9H-sf.cif.gz
# 5Q9I.cif.gz
# 5Q9I.pdb.gz
# 5Q9I-sf.cif.gz
# 5Q9J.cif.gz
# 5Q9J.pdb.gz
# 5Q9J-sf.cif.gz
# 5Q9K.cif.gz
# 5Q9K.pdb.gz
# 5Q9K-sf.cif.gz
# 5Q9L.cif.gz
# 5Q9L.pdb.gz
# 5Q9L-sf.cif.gz
# 5Q9M.cif.gz
# 5Q9M.pdb.gz
# 5Q9M-sf.cif.gz
# 5Q9N.cif.gz
# 5Q9N.pdb.gz
# 5Q9N-sf.cif.gz
# 5Q9O.cif.gz
# 5Q9O.pdb.gz
# 5Q9O-sf.cif.gz
# 5Q9P.cif.gz
# 5Q9P.pdb.gz
# 5Q9P-sf.cif.gz
# 5Q9Q.cif.gz
# 5Q9Q.pdb.gz
# 5Q9Q-sf.cif.gz
# 5Q9R.cif.gz
# 5Q9R.pdb.gz
# 5Q9R-sf.cif.gz
# 5Q9S.cif.gz
# 5Q9S.pdb.gz
# 5Q9S-sf.cif.gz
# 5Q9T.cif.gz
# 5Q9T.pdb.gz
# 5Q9T-sf.cif.gz
# 5Q9U.cif.gz
# 5Q9U.pdb.gz
# 5Q9U-sf.cif.gz
# 5Q9V.cif.gz
# 5Q9V.pdb.gz
# 5Q9V-sf.cif.gz
# 5Q9W.cif.gz
# 5Q9W.pdb.gz
# 5Q9W-sf.cif.gz
# 5Q9X.cif.gz
# 5Q9X.pdb.gz
# 5Q9X-sf.cif.gz
# 5Q9Y.cif.gz
# 5Q9Y.pdb.gz
# 5Q9Y-sf.cif.gz
# 5Q9Z.cif.gz
# 5Q9Z.pdb.gz
# 5Q9Z-sf.cif.gz
# 5QA0.cif.gz
# 5QA0.pdb.gz
# 5QA0-sf.cif.gz
# 5QA1.cif.gz
# 5QA1.pdb.gz
# 5QA1-sf.cif.gz
# 5QA2.cif.gz
# 5QA2.pdb.gz
# 5QA2-sf.cif.gz
# 5ULY.cif.gz
# 5ULY.pdb.gz
# 5ULY-sf.cif.gz
# 5VJA.cif.gz
# 5VJA.pdb.gz
# 5VJA-sf.cif.gz
# 5VTL.cif.gz
# 5VTL.pdb.gz
# 5VTL-sf.cif.gz
# 5WID.cif.gz
# 5WID.pdb.gz
# 5WID-sf.cif.gz
# 5WMI.cif.gz
# 5WMI.pdb.gz
# 5WMI-sf.cif.gz
# 5WMK.cif.gz
# 5WMK.pdb.gz
# 5WMK-sf.cif.gz
# 5WML.cif.gz
# 5WML.pdb.gz
# 5WML-sf.cif.gz
# 5WP1.cif.gz
# 5WP1.pdb.gz
# 5WP1-sf.cif.gz
# 5WYN.cif.gz
# 5WYN.pdb.gz
# 5WYN-sf.cif.gz
# 5X2I.cif.gz
# 5X2I.pdb.gz
# 5X2I-sf.cif.gz
# 5XXG.cif.gz
# 5XXG.pdb.gz
# 5XXG-sf.cif.gz
# 5XXJ.cif.gz
# 5XXJ.pdb.gz
# 5XXJ-sf.cif.gz
# 5XXQ.cif.gz
# 5XXQ.pdb.gz
# 5XXQ-sf.cif.gz
# 5XYR.cif.gz
# 5XYR.pdb.gz
# 5XYR-sf.cif.gz
# 5Y0E.cif.gz
# 5Y0E.pdb.gz
# 5Y0E-sf.cif.gz
# 5Y2I.cif.gz
# 5Y2I.pdb.gz
# 5Y2I-sf.cif.gz
# 5Y2P.cif.gz
# 5Y2P.pdb.gz
# 5Y2P-sf.cif.gz
# 5Y2Q.cif.gz
# 5Y2Q.pdb.gz
# 5Y2Q-sf.cif.gz
# 5Y2U.cif.gz
# 5Y2U.pdb.gz
# 5Y2U-sf.cif.gz
# 5Y35.cif.gz
# 5Y35.pdb.gz
# 5Y35-sf.cif.gz
# 5Y3I.cif.gz
# 5Y3I.pdb.gz
# 5Y3I-sf.cif.gz
# 5Y42.cif.gz
# 5Y42.pdb.gz
# 5Y42-sf.cif.gz
# 5Y4A.cif.gz
# 5Y4A.pdb.gz
# 5Y4A-sf.cif.gz
# 5Y4M.cif.gz
# 5Y4M.pdb.gz
# 5Y4M-sf.cif.gz
# 5Y4N.cif.gz
# 5Y4N.pdb.gz
# 5Y4N-sf.cif.gz
# 5Y4P.cif.gz
# 5Y4P.pdb.gz
# 5Y4P-sf.cif.gz
# 5Y4Q.cif.gz
# 5Y4Q.pdb.gz
# 5Y4Q-sf.cif.gz
# 5Y51.cif.gz
# 5Y51.pdb.gz
# 5Y51-sf.cif.gz
# 5Y52.cif.gz
# 5Y52.pdb.gz
# 5Y52-sf.cif.gz
# 5Y57.cif.gz
# 5Y57.pdb.gz
# 5Y57-sf.cif.gz
# 5Y5B.cif.gz
# 5Y5B.pdb.gz
# 5Y5B-sf.cif.gz
# 5Y5C.cif.gz
# 5Y5C.pdb.gz
# 5Y5C-sf.cif.gz
# 5Y5M.cif.gz
# 5Y5M.pdb.gz
# 5Y5M-sf.cif.gz
# 5YAK.cif.gz
# 5YAK.pdb.gz
# 5YAK-sf.cif.gz
# 5YGX.cif.gz
# 5YGX.pdb.gz
# 5YGX-sf.cif.gz
# 5YSX.cif.gz
# 5YSX.pdb.gz
# 5YSX-sf.cif.gz
# 5YT7.cif.gz
# 5YT7.pdb.gz
# 5YT7-sf.cif.gz
# 5YVF.cif.gz
# 5YVF.pdb.gz
# 5YVF-sf.cif.gz
# 5YYL.cif.gz
# 5YYL.pdb.gz
# 5YYL-sf.cif.gz
# 5Z2M.cif.gz
# 5Z2M.pdb.gz
# 5Z2M-sf.cif.gz
# 5Z2N.cif.gz
# 5Z2N.pdb.gz
# 5Z2N-sf.cif.gz
# 5ZC2.cif.gz
# 5ZC2.pdb.gz
# 5ZC2-sf.cif.gz
# 5ZEN.cif.gz
# 5ZEN.pdb.gz
# 5ZEN-sf.cif.gz
# 5ZJ4.cif.gz
# 5ZJ4.pdb.gz
# 5ZJ4-sf.cif.gz
# 5ZJ5.cif.gz
# 5ZJ5.pdb.gz
# 5ZJ5-sf.cif.gz
# 5ZMU.cif.gz
# 5ZMU.pdb.gz
# 5ZMU-sf.cif.gz
# 5ZMY.cif.gz
# 5ZMY.pdb.gz
# 5ZMY-sf.cif.gz
# 5ZRF.cif.gz
# 5ZRF.pdb.gz
# 5ZRF-sf.cif.gz
# 6A2F.cif.gz
# 6A2F.pdb.gz
# 6A2F-sf.cif.gz
# 6A90.cif.gz
# 6A90.pdb.gz
# 6A95.cif.gz
# 6A95.pdb.gz
# 6ALC.cif.gz
# 6ALC.pdb.gz
# 6ALC-sf.cif.gz
# 6ALE.cif.gz
# 6ALE.pdb.gz
# 6ALE-sf.cif.gz
# 6AM5.cif.gz
# 6AM5.pdb.gz
# 6AM5-sf.cif.gz
# 6AML.cif.gz
# 6AML.pdb.gz
# 6AML-sf.cif.gz
# 6AOC.cif.gz
# 6AOC.pdb.gz
# 6AOC-sf.cif.gz
# 6ATV.cif.gz
# 6ATV.pdb.gz
# 6ATV-sf.cif.gz
# 6AVK.cif.gz
# 6AVK.pdb.gz
# 6AVK-sf.cif.gz
# 6BHR.cif.gz
# 6BHR.pdb.gz
# 6BHR-sf.cif.gz
# 6BSL.cif.gz
# 6BSL.pdb.gz
# 6BSL-sf.cif.gz
# 6BSM.cif.gz
# 6BSM.pdb.gz
# 6BSM-sf.cif.gz
# 6BTN.cif.gz
# 6BTN.pdb.gz
# 6BTN-sf.cif.gz
# 6BTO.cif.gz
# 6BTO.pdb.gz
# 6BTO-sf.cif.gz
# 6BTP.cif.gz
# 6BTP.pdb.gz
# 6BTP-sf.cif.gz
# 6BTQ.cif.gz
# 6BTQ.pdb.gz
# 6BTQ-sf.cif.gz
# 6C63.cif.gz
# 6C63.pdb.gz
# 6C63-sf.cif.gz
# 6C65.cif.gz
# 6C65.pdb.gz
# 6C65-sf.cif.gz
# 6CJV.cif.gz
# 6CJV.pdb.gz
# 6CJV-sf.cif.gz
# 6CVW.cif.gz
# 6CVW.pdb.gz
# 6CVW-sf.cif.gz
# 6CVX.cif.gz
# 6CVX.pdb.gz
# 6CVX-sf.cif.gz
# 6CVY.cif.gz
# 6CVY.pdb.gz
# 6CVY-sf.cif.gz
# 6CZK.cif.gz
# 6CZK.pdb.gz
# 6CZK-sf.cif.gz
# 6CZS.cif.gz
# 6CZS.pdb.gz
# 6CZS-sf.cif.gz
# 6D6A.cif.gz
# 6D6A.pdb.gz
# 6D6A-sf.cif.gz
# 6D6B.cif.gz
# 6D6B.pdb.gz
# 6D6B-sf.cif.gz
# 6D6C.cif.gz
# 6D6C.pdb.gz
# 6D6C-sf.cif.gz
# 6D6D.cif.gz
# 6D6D.pdb.gz
# 6D6D-sf.cif.gz
# 6D6L.cif.gz
# 6D6L.pdb.gz
# 6D6L-sf.cif.gz
# 6D6M.cif.gz
# 6D6M.pdb.gz
# 6D6M-sf.cif.gz
# 6D6N.cif.gz
# 6D6N.pdb.gz
# 6D6N-sf.cif.gz
# 6D6O.cif.gz
# 6D6O.pdb.gz
# 6D6O-sf.cif.gz
# 6D6P.cif.gz
# 6D6P.pdb.gz
# 6D6P-sf.cif.gz
# 6D95.cif.gz
# 6D95.pdb.gz
# 6D95-sf.cif.gz
# 6DCG.cif.gz
# 6DCG.pdb.gz
# 6DCG-sf.cif.gz
# 6DXT.cif.gz
# 6DXT.pdb.gz
# 6DXT-sf.cif.gz
# 6E2H.cif.gz
# 6E2H.pdb.gz
# 6E2H-sf.cif.gz
# 6E2P.cif.gz
# 6E2P.pdb.gz
# 6E2P-sf.cif.gz
# 6E2Q.cif.gz
# 6E2Q.pdb.gz
# 6E2Q-sf.cif.gz
# 6E68.cif.gz
# 6E68.pdb.gz
# 6E68-sf.cif.gz
# 6E85.cif.gz
# 6E85.pdb.gz
# 6E85-sf.cif.gz
# 6E9P.cif.gz
# 6E9P.pdb.gz
# 6E9P-sf.cif.gz
# 6EK9.cif.gz
# 6EK9.pdb.gz
# 6EK9-sf.cif.gz
# 6EKD.cif.gz
# 6EKD.pdb.gz
# 6EKD-sf.cif.gz
# 6EMH.cif.gz
# 6EMH.pdb.gz
# 6EMH-sf.cif.gz
# 6EQ9.cif.gz
# 6EQ9.pdb.gz
# 6EQ9-sf.cif.gz
# 6EUQ.cif.gz
# 6EUQ.pdb.gz
# 6EUQ-sf.cif.gz
# 6EXW.cif.gz
# 6EXW.pdb.gz
# 6EXW-sf.cif.gz
# 6EY2.cif.gz
# 6EY2.pdb.gz
# 6EY2-sf.cif.gz
# 6F3M.cif.gz
# 6F3M.pdb.gz
# 6F3M-sf.cif.gz
# 6F3N.cif.gz
# 6F3N.pdb.gz
# 6F3N-sf.cif.gz
# 6F3O.cif.gz
# 6F3O.pdb.gz
# 6F3O-sf.cif.gz
# 6F3P.cif.gz
# 6F3P.pdb.gz
# 6F3P-sf.cif.gz
# 6F3Q.cif.gz
# 6F3Q.pdb.gz
# 6F3Q-sf.cif.gz
# 6F5M.cif.gz
# 6F5M.pdb.gz
# 6F5M-sf.cif.gz
# 6F76.cif.gz
# 6F76.pdb.gz
# 6F76-sf.cif.gz
# 6FDD.cif.gz
# 6FDD.pdb.gz
# 6FDD-sf.cif.gz
# 6FDE.cif.gz
# 6FDE.pdb.gz
# 6FDE-sf.cif.gz
# 6FG4.cif.gz
# 6FG4.pdb.gz
# 6FG4-sf.cif.gz
# 6FGR.cif.gz
# 6FGR.pdb.gz
# 6FGR-sf.cif.gz
# 6FHC.cif.gz
# 6FHC.pdb.gz
# 6FHC-sf.cif.gz
# 6FHD.cif.gz
# 6FHD.pdb.gz
# 6FHD-sf.cif.gz
# 6FIY.cif.gz
# 6FIY.pdb.gz
# 6FIY-sf.cif.gz
# 6FKS.cif.gz
# 6FKS.pdb.gz
# 6FKS-sf.cif.gz
# 6FKT.cif.gz
# 6FKT.pdb.gz
# 6FKT-sf.cif.gz
# 6FL0.cif.gz
# 6FL0.pdb.gz
# 6FL0-sf.cif.gz
# 6FL2.cif.gz
# 6FL2.pdb.gz
# 6FL2-sf.cif.gz
# 6FMH.cif.gz
# 6FMH.pdb.gz
# 6FMH-sf.cif.gz
# 6FMP.cif.gz
# 6FMP.pdb.gz
# 6FMP-sf.cif.gz
# 6FMQ.cif.gz
# 6FMQ.pdb.gz
# 6FMQ-sf.cif.gz
# 6FNF.cif.gz
# 6FNF.pdb.gz
# 6FNF-sf.cif.gz
# 6FNG.cif.gz
# 6FNG.pdb.gz
# 6FNG-sf.cif.gz
# 6FNH.cif.gz
# 6FNH.pdb.gz
# 6FNH-sf.cif.gz
# 6FNI.cif.gz
# 6FNI.pdb.gz
# 6FNI-sf.cif.gz
# 6FNJ.cif.gz
# 6FNJ.pdb.gz
# 6FNJ-sf.cif.gz
# 6FNK.cif.gz
# 6FNK.pdb.gz
# 6FNK-sf.cif.gz
# 6FNL.cif.gz
# 6FNL.pdb.gz
# 6FNL-sf.cif.gz
# 6FNM.cif.gz
# 6FNM.pdb.gz
# 6FNM-sf.cif.gz
# 6FSQ.cif.gz
# 6FSQ.pdb.gz
# 6FSQ-sf.cif.gz
# 6FT5.cif.gz
# 6FT5.pdb.gz
# 6FT5-sf.cif.gz
# 6FWV.cif.gz
# 6FWV.pdb.gz
# 6FWV-sf.cif.gz
# 6FWY.cif.gz
# 6FWY.pdb.gz
# 6FWY-sf.cif.gz
# 6FX6.cif.gz
# 6FX6.pdb.gz
# 6FX6-sf.cif.gz
# 6G6Y.cif.gz
# 6G6Y.pdb.gz
# 6G6Y-sf.cif.gz
# 6G6Z.cif.gz
# 6G6Z.pdb.gz
# 6G6Z-sf.cif.gz
# 6G7X.cif.gz
# 6G7X.pdb.gz
# 6G7X-sf.cif.gz
# 6GBN.cif.gz
# 6GBN.pdb.gz
# 6GBN-sf.cif.gz
# 6GGM.cif.gz
# 6GGM.pdb.gz
# 6GGM-sf.cif.gz
# 6GH1.cif.gz
# 6GH1.pdb.gz
# 6GH1-sf.cif.gz
# 6GH4.cif.gz
# 6GH4.pdb.gz
# 6GH4-sf.cif.gz
# 6GHC.cif.gz
# 6GHC.pdb.gz
# 6GHC-sf.cif.gz
# 6GHD.cif.gz
# 6GHD.pdb.gz
# 6GHD-sf.cif.gz
# 6GHN.cif.gz
# 6GHN.pdb.gz
# 6GHN-sf.cif.gz
# 6GIM.cif.gz
# 6GIM.pdb.gz
# 6GIM-sf.cif.gz
# 6GK5.cif.gz
# 6GK5.pdb.gz
# 6GK5-sf.cif.gz
# 6GK6.cif.gz
# 6GK6.pdb.gz
# 6GK6-sf.cif.gz
# 6GL1.cif.gz
# 6GL1.pdb.gz
# 6GL1-sf.cif.gz
# 6GMN.cif.gz
# 6GMN.pdb.gz
# 6GMN-sf.cif.gz
# 6GMR.cif.gz
# 6GMR.pdb.gz
# 6GMR-sf.cif.gz
# 6GMX.cif.gz
# 6GMX.pdb.gz
# 6GMX-sf.cif.gz
# 6GPG.cif.gz
# 6GPG.pdb.gz
# 6GPG-sf.cif.gz
# 6GWR.cif.gz
# 6GWR.pdb.gz
# 6GWR-sf.cif.gz
# 6GXZ.cif.gz
# 6GXZ.pdb.gz
# 6GXZ-sf.cif.gz
# 6GY5.cif.gz
# 6GY5.pdb.gz
# 6GY5-sf.cif.gz
# 6H00.cif.gz
# 6H00.pdb.gz
# 6H00-sf.cif.gz
# 6H2J.cif.gz
# 6H2J.pdb.gz
# 6H2J-sf.cif.gz
# 6H7X.cif.gz
# 6H7X.pdb.gz
# 6H7X-sf.cif.gz
# 5LSF.cif.gz
# 5LSF.pdb.gz
# 5LSF-sf.cif.gz
# 5MLH.cif.gz
# 5MLH.pdb.gz
# 5MLH-sf.cif.gz
# 5MLM.cif.gz
# 5MLM.pdb.gz
# 5MLM-sf.cif.gz
# 5MLR.cif.gz
# 5MLR.pdb.gz
# 5MLR-sf.cif.gz
# 5MPV.cif.gz
# 5MPV.pdb.gz
# 5MPV-sf.cif.gz
# 5OA0.cif.gz
# 5OA0.pdb.gz
# 5OA0-sf.cif.gz
# 5OAB.cif.gz
# 5OAB.pdb.gz
# 5OAB-sf.cif.gz
# 5OAD.cif.gz
# 5OAD.pdb.gz
# 5OAD-sf.cif.gz
# 5OAH.cif.gz
# 5OAH.pdb.gz
# 5OAH-sf.cif.gz
# 5OAJ.cif.gz
# 5OAJ.pdb.gz
# 5OAJ-sf.cif.gz
# 5OBG.cif.gz
# 5OBG.pdb.gz
# 5OBG-sf.cif.gz
# 5OBH.cif.gz
# 5OBH.pdb.gz
# 5OBH-sf.cif.gz
# 5OBO.cif.gz
# 5OBO.pdb.gz
# 5OBO-sf.cif.gz
# 5OCP.cif.gz
# 5OCP.pdb.gz
# 5OCP-sf.cif.gz
# 5OD5.cif.gz
# 5OD5.pdb.gz
# 5OD5-sf.cif.gz
# 5ODN.cif.gz
# 5ODN.pdb.gz
# 5ODN-sf.cif.gz
# 5ODP.cif.gz
# 5ODP.pdb.gz
# 5ODP-sf.cif.gz
# 5OEX.cif.gz
# 5OEX.pdb.gz
# 5OEX-sf.cif.gz
# 5OF0.cif.gz
# 5OF0.pdb.gz
# 5OF0-sf.cif.gz
# 5OG9.cif.gz
# 5OG9.pdb.gz
# 5OG9-sf.cif.gz
# 5OGH.cif.gz
# 5OGH.pdb.gz
# 5OGH-sf.cif.gz
# 5OGJ.cif.gz
# 5OGJ.pdb.gz
# 5OGJ-sf.cif.gz
# 5OGN.cif.gz
# 5OGN.pdb.gz
# 5OGN-sf.cif.gz
# 5OGO.cif.gz
# 5OGO.pdb.gz
# 5OGO-sf.cif.gz
# 5OGP.cif.gz
# 5OGP.pdb.gz
# 5OGP-sf.cif.gz
# 5OGT.cif.gz
# 5OGT.pdb.gz
# 5OGT-sf.cif.gz
# 5OGZ.cif.gz
# 5OGZ.pdb.gz
# 5OGZ-sf.cif.gz
# 5OHC.cif.gz
# 5OHC.pdb.gz
# 5OHC-sf.cif.gz
# 5OW8.cif.gz
# 5OW8.pdb.gz
# 5OW8-sf.cif.gz
# 5OWC.cif.gz
# 5OWC.pdb.gz
# 5OWC-sf.cif.gz
# 5WFI.cif.gz
# 5WFI.pdb.gz
# 5WFI-sf.cif.gz
# 5WIJ.cif.gz
# 5WIJ.pdb.gz
# 5WIJ-sf.cif.gz
# 5WIK.cif.gz
# 5WIK.pdb.gz
# 5WIK-sf.cif.gz
# 5WIL.cif.gz
# 5WIL.pdb.gz
# 5WIL-sf.cif.gz
# 5WIM.cif.gz
# 5WIM.pdb.gz
# 5WIM-sf.cif.gz
# 5WIN.cif.gz
# 5WIN.pdb.gz
# 5WIN-sf.cif.gz
# 5WKZ.cif.gz
# 5WKZ.pdb.gz
# 5WKZ-sf.cif.gz
# 5WL2.cif.gz
# 5WL2.pdb.gz
# 5WL2-sf.cif.gz
# 5WLR.cif.gz
# 5WLR.pdb.gz
# 5WLR-sf.cif.gz
# 5WLT.cif.gz
# 5WLT.pdb.gz
# 5WLT-sf.cif.gz
# 5WLU.cif.gz
# 5WLU.pdb.gz
# 5WLU-sf.cif.gz
# 5WLV.cif.gz
# 5WLV.pdb.gz
# 5WLV-sf.cif.gz
# 5WMA.cif.gz
# 5WMA.pdb.gz
# 5WMA-sf.cif.gz
# 5WMD.cif.gz
# 5WMD.pdb.gz
# 5WMD-sf.cif.gz
# 5WMG.cif.gz
# 5WMG.pdb.gz
# 5WMG-sf.cif.gz
# 5WNE.cif.gz
# 5WNE.pdb.gz
# 5WNE-sf.cif.gz
# 5WNF.cif.gz
# 5WNF.pdb.gz
# 5WNF-sf.cif.gz
# 5WNG.cif.gz
# 5WNG.pdb.gz
# 5WNG-sf.cif.gz
# 5XNE.cif.gz
# 5XNE.pdb.gz
# 5XNE-sf.cif.gz
# 5Y07.cif.gz
# 5Y07.pdb.gz
# 5Y07-sf.cif.gz
# 5Y19.cif.gz
# 5Y19.pdb.gz
# 5Y19-sf.cif.gz
# 5Y1H.cif.gz
# 5Y1H.pdb.gz
# 5Y1H-sf.cif.gz
# 5Y1K.cif.gz
# 5Y1K.pdb.gz
# 5Y1K-sf.cif.gz
# 5Y1Q.cif.gz
# 5Y1Q.pdb.gz
# 5Y1Q-sf.cif.gz
# 5Y1R.cif.gz
# 5Y1R.pdb.gz
# 5Y1R-sf.cif.gz
# 5Y1S.cif.gz
# 5Y1S.pdb.gz
# 5Y1S-sf.cif.gz
# 5Y1T.cif.gz
# 5Y1T.pdb.gz
# 5Y1T-sf.cif.gz
# 5Y1V.cif.gz
# 5Y1V.pdb.gz
# 5Y1V-sf.cif.gz
# 5Y1W.cif.gz
# 5Y1W.pdb.gz
# 5Y1W-sf.cif.gz
# 5Y1X.cif.gz
# 5Y1X.pdb.gz
# 5Y1X-sf.cif.gz
# 5Y3S.cif.gz
# 5Y3S.pdb.gz
# 5Y3S-sf.cif.gz
# 5Y7X.cif.gz
# 5Y7X.pdb.gz
# 5Y7X-sf.cif.gz
# 5Y9P.cif.gz
# 5Y9P.pdb.gz
# 5Y9P-sf.cif.gz
# 5YF0.cif.gz
# 5YF0.pdb.gz
# 5YF0-sf.cif.gz
# 5YF1.cif.gz
# 5YF1.pdb.gz
# 5YF1-sf.cif.gz
# 5YF2.cif.gz
# 5YF2.pdb.gz
# 5YF2-sf.cif.gz
# 5YH1.cif.gz
# 5YH1.pdb.gz
# 5YH1-sf.cif.gz
# 5YUI.cif.gz
# 5YUI.pdb.gz
# 5YUI-sf.cif.gz
# 5YUJ.cif.gz
# 5YUJ.pdb.gz
# 5YUJ-sf.cif.gz
# 5YUK.cif.gz
# 5YUK.pdb.gz
# 5YUK-sf.cif.gz
# 5YY2.cif.gz
# 5YY2.pdb.gz
# 5YY2-sf.cif.gz
# 5YY3.cif.gz
# 6DOC-sf.cif.gz
# 6DOD.cif.gz
# 6DOD.pdb.gz
# 6DOD-sf.cif.gz
# 6DOE.cif.gz
# 6DOE.pdb.gz
# 6DOE-sf.cif.gz
# 6DOF.cif.gz
# 6DOF.pdb.gz
# 6DOF-sf.cif.gz
# 6DOG.cif.gz
# 6DOG.pdb.gz
# 6DOG-sf.cif.gz
# 6DOH.cif.gz
# 6DOH.pdb.gz
# 6DOH-sf.cif.gz
# 6DOJ.cif.gz
# 6DOJ.pdb.gz
# 6DOJ-sf.cif.gz
# 6DOK.cif.gz
# 6DOK.pdb.gz
# 6DOK-sf.cif.gz
# 6DOL.cif.gz
# 6DOL.pdb.gz
# 6DOL-sf.cif.gz
# 6DOM.cif.gz
# 6DOM.pdb.gz
# 6DOM-sf.cif.gz
# 6DON.cif.gz
# 6DON.pdb.gz
# 6DON-sf.cif.gz
# 6DOO.cif.gz
# 6DOO.pdb.gz
# 6DOO-sf.cif.gz
# 6DOP.cif.gz
# 6DOP.pdb.gz
# 6DOP-sf.cif.gz
# 6DOQ.cif.gz
# 6DOQ.pdb.gz
# 6DOQ-sf.cif.gz
# 6DOR.cif.gz
# 6DOR.pdb.gz
# 6DOR-sf.cif.gz
# 6DOS.cif.gz
# 6DOS.pdb.gz
# 6DOS-sf.cif.gz
# 6DOT.cif.gz
# 6DOT.pdb.gz
# 6DOT-sf.cif.gz
# 6DOU.cif.gz
# 6DOU.pdb.gz
# 6DOU-sf.cif.gz
# 6DOV.cif.gz
# 6DOV.pdb.gz
# 6DOV-sf.cif.gz
# 6DOW.cif.gz
# 6DOW.pdb.gz
# 6DOW-sf.cif.gz
# 6DOX.cif.gz
# 6DOX.pdb.gz
# 6DOX-sf.cif.gz
# 6DOY.cif.gz
# 6DOY.pdb.gz
# 6DOY-sf.cif.gz
# 6DOZ.cif.gz
# 6DOZ.pdb.gz
# 6DOZ-sf.cif.gz
# 6DP0.cif.gz
# 6DP0.pdb.gz
# 6DP0-sf.cif.gz
# 6DP1.cif.gz
# 6DP1.pdb.gz
# 6DP1-sf.cif.gz
# 6DP2.cif.gz
# 6DP2.pdb.gz
# 6DP2-sf.cif.gz
# 6DP3.cif.gz
# 6DP3.pdb.gz
# 6DP3-sf.cif.gz
# 6DP4.cif.gz
# 6DP4.pdb.gz
# 6DP4-sf.cif.gz
# 6DP5.cif.gz
# 6DP5.pdb.gz
# 6DP5-sf.cif.gz
# 6DP6.cif.gz
# 6DP6.pdb.gz
# 6DP6-sf.cif.gz
# 6DP7.cif.gz
# 6DP7.pdb.gz
# 6DP7-sf.cif.gz
# 6DP8.cif.gz
# 6DP8.pdb.gz
# 6DP8-sf.cif.gz
# 6DP9.cif.gz
# 6DP9.pdb.gz
# 6DP9-sf.cif.gz
# 6DPA.cif.gz
# 6DPA.pdb.gz
# 6DPA-sf.cif.gz
# 6DPB.cif.gz
# 6DPB.pdb.gz
# 6DPB-sf.cif.gz
# 6DPC.cif.gz
# 6DPC.pdb.gz
# 6DPC-sf.cif.gz
# 6DPD.cif.gz
# 6DPD.pdb.gz
# 6DPD-sf.cif.gz
# 6DPE.cif.gz
# 6DPE.pdb.gz
# 6DPE-sf.cif.gz
# 6DPF.cif.gz
# 6DPF.pdb.gz
# 6DPF-sf.cif.gz
# 6DPG.cif.gz
# 6DPG.pdb.gz
# 6DPG-sf.cif.gz
# 6DPH.cif.gz
# 6DPH.pdb.gz
# 6DPH-sf.cif.gz
# 6DPI.cif.gz
# 6DPI.pdb.gz
# 6DPI-sf.cif.gz
# 6DPJ.cif.gz
# 6DPJ.pdb.gz
# 6DPJ-sf.cif.gz
# 6DPK.cif.gz
# 6DPK.pdb.gz
# 6DPK-sf.cif.gz
# 6DPL.cif.gz
# 6DPL.pdb.gz
# 6DPL-sf.cif.gz
# 6DPM.cif.gz
# 6DPM.pdb.gz
# 6DPM-sf.cif.gz
# 6DPN.cif.gz
# 6DPN.pdb.gz
# 6DPN-sf.cif.gz
# 6DPO.cif.gz
# 6DPO.pdb.gz
# 6DPO-sf.cif.gz
# 6DPP.cif.gz
# 6DPP.pdb.gz
# 6DPP-sf.cif.gz
# 6E8G.cif.gz
# 6E9D.cif.gz
# 6ES8.cif.gz
# 6ES8.pdb.gz
# 6ES8-sf.cif.gz
# 6ET8.cif.gz
# 6ET8.pdb.gz
# 6ET8-sf.cif.gz
# 6EYN.cif.gz
# 6EYN.pdb.gz
# 6EYN-sf.cif.gz
# 6EZY.cif.gz
# 6EZY.pdb.gz
# 6EZY-sf.cif.gz
# 6F01.cif.gz
# 6F01.pdb.gz
# 6F01-sf.cif.gz
# 6F05.cif.gz
# 6F05.pdb.gz
# 6F05-sf.cif.gz
# 6F1J.cif.gz
# 6F1J.pdb.gz
# 6F1J-sf.cif.gz
# 6F6Q.cif.gz
# 6F6Q.pdb.gz
# 6F6Q-sf.cif.gz
# 6F75.cif.gz
# 6F75.pdb.gz
# 6F75-sf.cif.gz
# 6F79.cif.gz
# 6F79.pdb.gz
# 6F79-sf.cif.gz
# 6FCH.cif.gz
# 6FCH.pdb.gz
# 6FCH-sf.cif.gz
# 6FCI.cif.gz
# 6FCI.pdb.gz
# 6FCI-sf.cif.gz
# 6FCL.cif.gz
# 6FCL.pdb.gz
# 6FCL-sf.cif.gz
# 6FD4.cif.gz
# 6FD4.pdb.gz
# 6FD4-sf.cif.gz
# 6FD5.cif.gz
# 6FD5.pdb.gz
# 6FD5-sf.cif.gz
# 6FD6.cif.gz
# 6FD6.pdb.gz
# 6FD6-sf.cif.gz
# 6FDK.cif.gz
# 6FDK.pdb.gz
# 6FDK-sf.cif.gz
# 6FDQ.cif.gz
# 6FDQ.pdb.gz
# 6FDQ-sf.cif.gz
# 6FDU.cif.gz
# 6FDU.pdb.gz
# 6FDU-sf.cif.gz
# 6FFJ.cif.gz
# 6FFJ.pdb.gz
# 6FFJ-sf.cif.gz
# 6FLS.cif.gz
# 6FLS.pdb.gz
# 6FLS-sf.cif.gz
# 6FLW.cif.gz
# 6FLW.pdb.gz
# 6FLW-sf.cif.gz
# 6FLY.cif.gz
# 6FLY.pdb.gz
# 6FLY-sf.cif.gz
# 6FLZ.cif.gz
# 6FLZ.pdb.gz
# 6FLZ-sf.cif.gz
# 6FTV.cif.gz
# 6FTV.pdb.gz
# 6FTV-sf.cif.gz
# 6G1G.cif.gz
# 6G1G.pdb.gz
# 6G1G-sf.cif.gz
# 6G1I.cif.gz
# 6G1I.pdb.gz
# 6G1I-sf.cif.gz
# 6GBI.cif.gz
# 6GBI.pdb.gz
# 6GBI-sf.cif.gz
# 6GL3.cif.gz
# 6GL3.pdb.gz
# 6GL3-sf.cif.gz
# 6GPC.cif.gz
# 6GPC.pdb.gz
# 6GPC-sf.cif.gz
# 6GPD.cif.gz
# 6GPD.pdb.gz
# 6GPD-sf.cif.gz
# 6GPM.cif.gz
# 6GPM.pdb.gz
# 6GPM-sf.cif.gz
# 6GQZ.cif.gz
# 6GQZ.pdb.gz
# 6GQZ-sf.cif.gz
# 6GR0.cif.gz
# 6GR0.pdb.gz
# 6GR0-sf.cif.gz
# 6GRW.cif.gz
# 6GRW.pdb.gz
# 6GRW-sf.cif.gz
# 6GRY.cif.gz
# 6GRY.pdb.gz
# 6GRY-sf.cif.gz
# 6GU8.cif.gz
# 6GU8.pdb.gz
# 6GU8-sf.cif.gz
# 6GUD.cif.gz
# 6GUD.pdb.gz
# 6GUD-sf.cif.gz
# 6GUG.cif.gz
# 6GUG.pdb.gz
# 6GUG-sf.cif.gz
# 6GUI.cif.gz
# 6GUI.pdb.gz
# 6GUI-sf.cif.gz
# 6GUL.cif.gz
# 6GUL.pdb.gz
# 6GUL-sf.cif.gz
# 6GUN.cif.gz
# 6GUN.pdb.gz
# 6GUN-sf.cif.gz
# 6GUO.cif.gz
# 6GUO.pdb.gz
# 6GUO-sf.cif.gz
# 6GUP.cif.gz
# 6GUP.pdb.gz
# 6GUP-sf.cif.gz
# 6GUR.cif.gz
# 6GUR.pdb.gz
# 6GUR-sf.cif.gz
# 6GX3.cif.gz
# 6GX3.pdb.gz
# 6GX3-sf.cif.gz
# 6GXA.cif.gz
# 6GXA.pdb.gz
# 6GXA-sf.cif.gz
# 6GXU.cif.gz
# 6GXU.pdb.gz
# 6GXU-sf.cif.gz
# 6GXW.cif.gz
# 6GXW.pdb.gz
# 6GXW-sf.cif.gz
# 6H09.cif.gz
# 6H09.pdb.gz
# 6H09-sf.cif.gz
# 6H2Q.cif.gz
# 6H2Q.pdb.gz
# 6H2Q-sf.cif.gz
# 6H8P.cif.gz
# 6H8P.pdb.gz
# 6H8P-sf.cif.gz
# 5MHE.cif.gz
# 5MHE.pdb.gz
# 5MHE-sf.cif.gz
# 5MHG.cif.gz
# 5MHG.pdb.gz
# 5MHG-sf.cif.gz
# 5NRN.cif.gz
# 5NRN.pdb.gz
# 5NRN-sf.cif.gz
# 5NRQ.cif.gz
# 5NRQ.pdb.gz
# 5NRQ-sf.cif.gz
# 5NS6.cif.gz
# 5NS6.pdb.gz
# 5NS6-sf.cif.gz
# 5NS7.cif.gz
# 5NS7.pdb.gz
# 5NS7-sf.cif.gz
# 5NS8.cif.gz
# 5NS8.pdb.gz
# 5NS8-sf.cif.gz
# 5OAN.cif.gz
# 5OAN.pdb.gz
# 5OAN-sf.cif.gz
# 5OG7.cif.gz
# 5OG7.pdb.gz
# 5OG7-sf.cif.gz
# 5OHH.cif.gz
# 5OHH.pdb.gz
# 5OHH-sf.cif.gz
# 5OHS.cif.gz
# 5OHS.pdb.gz
# 5OHS-sf.cif.gz
# 5OHT.cif.gz
# 5OHT.pdb.gz
# 5OHT-sf.cif.gz
# 5OHY.cif.gz
# 5OHY.pdb.gz
# 5OHY-sf.cif.gz
# 5OHZ.cif.gz
# 5OHZ.pdb.gz
# 5OHZ-sf.cif.gz
# 5OI0.cif.gz
# 5OI0.pdb.gz
# 5OI0-sf.cif.gz
# 5OI1.cif.gz
# 5OI1.pdb.gz
# 5OI1-sf.cif.gz
# 5OIE.cif.gz
# 5OIE.pdb.gz
# 5OIE-sf.cif.gz
# 5OIU.cif.gz
# 5OIU.pdb.gz
# 5OIU-sf.cif.gz
# 5OIV.cif.gz
# 5OIV.pdb.gz
# 5OIV-sf.cif.gz
# 5OIW.cif.gz
# 5OIW.pdb.gz
# 5OIW-sf.cif.gz
# 5OJ3.cif.gz
# 5OJ3.pdb.gz
# 5OJ3-sf.cif.gz
# 5OJ4.cif.gz
# 5OJ4.pdb.gz
# 5OJ4-sf.cif.gz
# 5OJ5.cif.gz
# 5OJ5.pdb.gz
# 5OJ5-sf.cif.gz
# 5OJH.cif.gz
# 5OJH.pdb.gz
# 5OJH-sf.cif.gz
# 5OJP.cif.gz
# 5OJP.pdb.gz
# 5OJP-sf.cif.gz
# 5OJR.cif.gz
# 5OJR.pdb.gz
# 5OJR-sf.cif.gz
# 5OJU.cif.gz
# 5OJU.pdb.gz
# 5OJU-sf.cif.gz
# 5OJV.cif.gz
# 5OJV.pdb.gz
# 5OJV-sf.cif.gz
# 5OK3.cif.gz
# 5OK3.pdb.gz
# 5OK3-sf.cif.gz
# 5OK6.cif.gz
# 5OK6.pdb.gz
# 5OK6-sf.cif.gz
# 5OLL.cif.gz
# 5OLL.pdb.gz
# 5OLL-sf.cif.gz
# 5OLT.cif.gz
# 5OLT.pdb.gz
# 5OLT-sf.cif.gz
# 5Q1J.cif.gz
# 5Q1J.pdb.gz
# 5Q1J-sf.cif.gz
# 5Q1K.cif.gz
# 5Q1K.pdb.gz
# 5Q1K-sf.cif.gz
# 5Q1L.cif.gz
# 5Q1L.pdb.gz
# 5Q1L-sf.cif.gz
# 5Q1M.cif.gz
# 5Q1M.pdb.gz
# 5Q1M-sf.cif.gz
# 5Q1N.cif.gz
# 5Q1N.pdb.gz
# 5Q1N-sf.cif.gz
# 5Q1O.cif.gz
# 5Q1O.pdb.gz
# 5Q1O-sf.cif.gz
# 5Q1P.cif.gz
# 5Q1P.pdb.gz
# 5Q1P-sf.cif.gz
# 5Q1Q.cif.gz
# 5Q1Q.pdb.gz
# 5Q1Q-sf.cif.gz
# 5Q1R.cif.gz
# 5Q1R.pdb.gz
# 5Q1R-sf.cif.gz
# 5Q1S.cif.gz
# 5Q1S.pdb.gz
# 5Q1S-sf.cif.gz
# 5Q1T.cif.gz
# 5Q1T.pdb.gz
# 5Q1T-sf.cif.gz
# 5Q1U.cif.gz
# 5Q1U.pdb.gz
# 5Q1U-sf.cif.gz
# 5Q1V.cif.gz
# 5Q1V.pdb.gz
# 5Q1V-sf.cif.gz
# 5Q1W.cif.gz
# 5Q1W.pdb.gz
# 5Q1W-sf.cif.gz
# 5Q1X.cif.gz
# 5Q1X.pdb.gz
# 5Q1X-sf.cif.gz
# 5Q1Y.cif.gz
# 5Q1Y.pdb.gz
# 5Q1Y-sf.cif.gz
# 5Q1Z.cif.gz
# 5Q1Z.pdb.gz
# 5Q1Z-sf.cif.gz
# 5Q20.cif.gz
# 5Q20.pdb.gz
# 5Q20-sf.cif.gz
# 5Q22.cif.gz
# 5Q22.pdb.gz
# 5Q22-sf.cif.gz
# 5Q23.cif.gz
# 5Q23.pdb.gz
# 5Q23-sf.cif.gz
# 5Q24.cif.gz
# 5Q24.pdb.gz
# 5Q24-sf.cif.gz
# 5Q25.cif.gz
# 5Q25.pdb.gz
# 5Q25-sf.cif.gz
# 5Q26.cif.gz
# 5Q26.pdb.gz
# 5Q26-sf.cif.gz
# 5Q27.cif.gz
# 5Q27.pdb.gz
# 5Q27-sf.cif.gz
# 5Q28.cif.gz
# 5Q28.pdb.gz
# 5Q28-sf.cif.gz
# 5Q29.cif.gz
# 5Q29.pdb.gz
# 5Q29-sf.cif.gz
# 5Q2A.cif.gz
# 5Q2A.pdb.gz
# 5Q2A-sf.cif.gz
# 5Q2B.cif.gz
# 5Q2B.pdb.gz
# 5Q2B-sf.cif.gz
# 5Q2C.cif.gz
# 5Q2C.pdb.gz
# 5Q2C-sf.cif.gz
# 5Q2D.cif.gz
# 5Q2D.pdb.gz
# 5Q2D-sf.cif.gz
# 5Q2E.cif.gz
# 5Q2E.pdb.gz
# 5Q2E-sf.cif.gz
# 5Q2F.cif.gz
# 5Q2F.pdb.gz
# 5Q2F-sf.cif.gz
# 5Q2G.cif.gz
# 5Q2G.pdb.gz
# 5Q2G-sf.cif.gz
# 5Q2H.cif.gz
# 5Q2H.pdb.gz
# 5Q2H-sf.cif.gz
# 5Q2I.cif.gz
# 5Q2I.pdb.gz
# 5Q2I-sf.cif.gz
# 5Q2J.cif.gz
# 5Q2J.pdb.gz
# 5Q2J-sf.cif.gz
# 5Q2K.cif.gz
# 5Q2K.pdb.gz
# 5Q2K-sf.cif.gz
# 5Q2L.cif.gz
# 5Q2L.pdb.gz
# 5Q2L-sf.cif.gz
# 5Q2M.cif.gz
# 5Q2M.pdb.gz
# 5Q2M-sf.cif.gz
# 5Q2N.cif.gz
# 5Q2N.pdb.gz
# 5Q2N-sf.cif.gz
# 5Q2O.cif.gz
# 5Q2O.pdb.gz
# 5Q2O-sf.cif.gz
# 5Q2P.cif.gz
# 5Q2P.pdb.gz
# 5Q2P-sf.cif.gz
# 5Q2Q.cif.gz
# 5Q2Q.pdb.gz
# 5Q2Q-sf.cif.gz
# 5Q2R.cif.gz
# 5Q2R.pdb.gz
# 5Q2R-sf.cif.gz
# 5Q2S.cif.gz
# 5Q2S.pdb.gz
# 5Q2S-sf.cif.gz
# 5Q2T.cif.gz
# 5Q2T.pdb.gz
# 5Q2T-sf.cif.gz
# 5Q2U.cif.gz
# 5Q2U.pdb.gz
# 5Q2U-sf.cif.gz
# 5Q2V.cif.gz
# 5Q2V.pdb.gz
# 5Q2V-sf.cif.gz
# 5Q2W.cif.gz
# 5Q2W.pdb.gz
# 5Q2W-sf.cif.gz
# 5Q2X.cif.gz
# 5Q2X.pdb.gz
# 5Q2X-sf.cif.gz
# 5Q2Y.cif.gz
# 5Q2Y.pdb.gz
# 5Q2Y-sf.cif.gz
# 5Q2Z.cif.gz
# 5Q2Z.pdb.gz
# 5Q2Z-sf.cif.gz
# 5Q30.cif.gz
# 5Q30.pdb.gz
# 5Q30-sf.cif.gz
# 5Q31.cif.gz
# 5Q31.pdb.gz
# 5Q31-sf.cif.gz
# 5Q32.cif.gz
# 5Q32.pdb.gz
# 5Q32-sf.cif.gz
# 5Q33.cif.gz
# 5Q33.pdb.gz
# 5Q33-sf.cif.gz
# 5Q34.cif.gz
# 5Q34.pdb.gz
# 5Q34-sf.cif.gz
# 5Q35.cif.gz
# 5Q35.pdb.gz
# 5Q35-sf.cif.gz
# 5Q36.cif.gz
# 5Q36.pdb.gz
# 5Q36-sf.cif.gz
# 5Q37.cif.gz
# 5Q37.pdb.gz
# 5Q37-sf.cif.gz
# 5Q38.cif.gz
# 5Q38.pdb.gz
# 5Q38-sf.cif.gz
# 5Q39.cif.gz
# 5Q39.pdb.gz
# 5Q39-sf.cif.gz
# 5Q3A.cif.gz
# 5Q3A.pdb.gz
# 5Q3A-sf.cif.gz
# 5Q3B.cif.gz
# 5Q3B.pdb.gz
# 5Q3B-sf.cif.gz
# 5Q3C.cif.gz
# 5Q3C.pdb.gz
# 5Q3C-sf.cif.gz
# 5Q3D.cif.gz
# 5Q3D.pdb.gz
# 5Q3D-sf.cif.gz
# 5Q3E.cif.gz
# 5Q3E.pdb.gz
# 5Q3E-sf.cif.gz
# 5Q3F.cif.gz
# 5Q3F.pdb.gz
# 5Q3F-sf.cif.gz
# 5Q3G.cif.gz
# 5Q3G.pdb.gz
# 5Q3G-sf.cif.gz
# 5Q3H.cif.gz
# 5Q3H.pdb.gz
# 5Q3H-sf.cif.gz
# 5Q3I.cif.gz
# 5Q3I.pdb.gz
# 5Q3I-sf.cif.gz
# 5Q3J.cif.gz
# 5Q3J.pdb.gz
# 5Q3J-sf.cif.gz
# 5Q3K.cif.gz
# 5Q3K.pdb.gz
# 5Q3K-sf.cif.gz
# 5Q3L.cif.gz
# 5Q3L.pdb.gz
# 5Q3L-sf.cif.gz
# 5Q3M.cif.gz
# 5Q3M.pdb.gz
# 5Q3M-sf.cif.gz
# 5Q3N.cif.gz
# 5Q3N.pdb.gz
# 5Q3N-sf.cif.gz
# 5Q3O.cif.gz
# 5Q3O.pdb.gz
# 5Q3O-sf.cif.gz
# 5Q3P.cif.gz
# 5Q3P.pdb.gz
# 5Q3P-sf.cif.gz
# 5Q3Q.cif.gz
# 5Q3Q.pdb.gz
# 5Q3Q-sf.cif.gz
# 5Q3R.cif.gz
# 5Q3R.pdb.gz
# 5Q3R-sf.cif.gz
# 5Q3S.cif.gz
# 5Q3S.pdb.gz
# ...
# 5Q4J-sf.cif.gz
# 5Q4K.cif.gz
# 5Q4K.pdb.gz
# 5Q4K-sf.cif.gz
# 5Q4L.cif.gz
# 5Q4L.pdb.gz
# 5Q4L-sf.cif.gz
# 5Q4M.cif.gz
# 5Q4M.pdb.gz
# 5Q4M-sf.cif.gz
# 5Q4N.cif.gz
# 5Q4N.pdb.gz
# 5Q4N-sf.cif.gz
# 5Q4O.cif.gz
# 5Q4O.pdb.gz
# 5Q4O-sf.cif.gz
# 5Q4P.cif.gz
# 5Q4P.pdb.gz
# 5Q4P-sf.cif.gz
# 5Q4Q.cif.gz
# 5Q4Q.pdb.gz
# 5Q4Q-sf.cif.gz
# 5Q4R.cif.gz
# 5Q4R.pdb.gz
# 5Q4R-sf.cif.gz
# 5Q4S.cif.gz
# 5Q4S.pdb.gz
# 5Q4S-sf.cif.gz
# 5Q4T.cif.gz
# 5Q4T.pdb.gz
# 5Q4T-sf.cif.gz
# 5Q4U.cif.gz
# 5Q4U.pdb.gz
# 5Q4U-sf.cif.gz
# 5Q4V.cif.gz
# 5Q4V.pdb.gz
# 5Q4V-sf.cif.gz
# 5Q4W.cif.gz
# 5Q4W.pdb.gz
# 5Q4W-sf.cif.gz
# 5Q4X.cif.gz
# 5Q4X.pdb.gz
# 5Q4X-sf.cif.gz
# 5Q4Y.cif.gz
# 5Q4Y.pdb.gz
# 5Q4Y-sf.cif.gz
# 5Q4Z.cif.gz
# 5Q4Z.pdb.gz
# 5Q4Z-sf.cif.gz
# 5Q50.cif.gz
# 5Q50.pdb.gz
# 5Q50-sf.cif.gz
# 5Q51.cif.gz
# 5Q51.pdb.gz
# 5Q51-sf.cif.gz
# 5Q52.cif.gz
# 5Q52.pdb.gz
# 5Q52-sf.cif.gz
# 5Q53.cif.gz
# 5Q53.pdb.gz
# 5Q53-sf.cif.gz
# 5Q54.cif.gz
# 5Q54.pdb.gz
# 5Q54-sf.cif.gz
# 5Q55.cif.gz
# 5Q55.pdb.gz
# 5Q55-sf.cif.gz
# 5Q56.cif.gz
# 5Q56.pdb.gz
# 5Q56-sf.cif.gz
# 5Q57.cif.gz
# 5Q57.pdb.gz
# 5Q57-sf.cif.gz
# 5Q58.cif.gz
# 5Q58.pdb.gz
# 5Q58-sf.cif.gz
# 5Q59.cif.gz
# 5Q59.pdb.gz
# 5Q59-sf.cif.gz
# 5Q5A.cif.gz
# 5Q5A.pdb.gz
# 5Q5A-sf.cif.gz
# 5Q5B.cif.gz
# 5Q5B.pdb.gz
# 5Q5B-sf.cif.gz
# 5Q5C.cif.gz
# 5Q5C.pdb.gz
# 5Q5C-sf.cif.gz
# 5Q5D.cif.gz
# 5Q5D.pdb.gz
# 5Q5D-sf.cif.gz
# 5Q5E.cif.gz
# 5Q5E.pdb.gz
# 5Q5E-sf.cif.gz
# 5Q5F.cif.gz
# 5Q5F.pdb.gz
# 5Q5F-sf.cif.gz
# 5Q5G.cif.gz
# 5Q5G.pdb.gz
# 5Q5G-sf.cif.gz
# 5Q5H.cif.gz
# 5Q5H.pdb.gz
# 5Q5H-sf.cif.gz
# 5Q5I.cif.gz
# 5Q5I.pdb.gz
# 5Q5I-sf.cif.gz
# 5Q5J.cif.gz
# 5Q5J.pdb.gz
# 5Q5J-sf.cif.gz
# 5Q5K.cif.gz
# 5Q5K.pdb.gz
# 5Q5K-sf.cif.gz
# 5Q5L.cif.gz
# 5Q5L.pdb.gz
# 5Q5L-sf.cif.gz
# 5Q5M.cif.gz
# 5Q5M.pdb.gz
# 5Q5M-sf.cif.gz
# 5Q5N.cif.gz
# 5Q5N.pdb.gz
# 5Q5N-sf.cif.gz
# 5Q5O.cif.gz
# 5Q5O.pdb.gz
# 5Q5O-sf.cif.gz
# 5Q5P.cif.gz
# 5Q5P.pdb.gz
# 5Q5P-sf.cif.gz
# 5Q5Q.cif.gz
# 5Q5Q.pdb.gz
# 5Q5Q-sf.cif.gz
# 5Q5R.cif.gz
# 5Q5R.pdb.gz
# 5Q5R-sf.cif.gz
# 5Q5S.cif.gz
# 5Q5S.pdb.gz
# 5Q5S-sf.cif.gz
# 5Q5T.cif.gz
# 5Q5T.pdb.gz
# 5Q5T-sf.cif.gz
# 5Q5U.cif.gz
# 5Q5U.pdb.gz
# 5Q5U-sf.cif.gz
# 5Q5V.cif.gz
# 5Q5V.pdb.gz
# 5Q5V-sf.cif.gz
# 5Q5W.cif.gz
# 5Q5W.pdb.gz
# 5Q5W-sf.cif.gz
# 5Q5X.cif.gz
# 5Q5X.pdb.gz
# 5Q5X-sf.cif.gz
# 5Q5Y.cif.gz
# 5Q5Y.pdb.gz
# 5Q5Y-sf.cif.gz
# 5Q5Z.cif.gz
# 5Q5Z.pdb.gz
# 5Q5Z-sf.cif.gz
# 5Q60.cif.gz
# 5Q60.pdb.gz
# 5Q60-sf.cif.gz
# 5Q61.cif.gz
# 5Q61.pdb.gz
# 5Q61-sf.cif.gz
# 5Q62.cif.gz
# 5Q62.pdb.gz
# 5Q62-sf.cif.gz
# 5Q63.cif.gz
# 5Q63.pdb.gz
# 5Q63-sf.cif.gz
# 5Q64.cif.gz
# 5Q64.pdb.gz
# 5Q64-sf.cif.gz
# 5Q65.cif.gz
# 5Q65.pdb.gz
# 5Q65-sf.cif.gz
# 5Q66.cif.gz
# 5Q66.pdb.gz
# 5Q66-sf.cif.gz
# 5Q67.cif.gz
# 5Q67.pdb.gz
# 5Q67-sf.cif.gz
# 5Q68.cif.gz
# 5Q68.pdb.gz
# 5Q68-sf.cif.gz
# 5Q69.cif.gz
# 5Q69.pdb.gz
# 5Q69-sf.cif.gz
# 5Q6A.cif.gz
# 5Q6A.pdb.gz
# 5Q6A-sf.cif.gz
# 5Q6B.cif.gz
# 5Q6B.pdb.gz
# 5Q6B-sf.cif.gz
# 5Q6C.cif.gz
# 5Q6C.pdb.gz
# 5Q6C-sf.cif.gz
# 5Q6D.cif.gz
# 5Q6D.pdb.gz
# 5Q6D-sf.cif.gz
# 5Q6E.cif.gz
# 5Q6E.pdb.gz
# 5Q6E-sf.cif.gz
# 5Q6F.cif.gz
# 5Q6F.pdb.gz
# 5Q6F-sf.cif.gz
# 5Q6G.cif.gz
# 5Q6G.pdb.gz
# 5Q6G-sf.cif.gz
# 5Q6H.cif.gz
# 5Q6H.pdb.gz
# 5Q6H-sf.cif.gz
# 5Q6I.cif.gz
# 5Q6I.pdb.gz
# 5Q6I-sf.cif.gz
# 5Q6J.cif.gz
# 5Q6J.pdb.gz
# 5Q6J-sf.cif.gz
# 5Q6K.cif.gz
# 5Q6K.pdb.gz
# 5Q6K-sf.cif.gz
# 5Q6L.cif.gz
# 5Q6L.pdb.gz
# 5Q6L-sf.cif.gz
# 5Q6M.cif.gz
# 5Q6M.pdb.gz
# 5Q6M-sf.cif.gz
# 5Q6N.cif.gz
# 5Q6N.pdb.gz
# 5Q6N-sf.cif.gz
# 5Q6O.cif.gz
# 5Q6O.pdb.gz
# 5Q6O-sf.cif.gz
# 5Q6P.cif.gz
# 5Q6P.pdb.gz
# 5Q6P-sf.cif.gz
# 5Q6Q.cif.gz
# 5Q6Q.pdb.gz
# 5Q6Q-sf.cif.gz
# 5Q6R.cif.gz
# 5Q6R.pdb.gz
# 5Q6R-sf.cif.gz
# 5Q6S.cif.gz
# 5Q6S.pdb.gz
# 5Q6S-sf.cif.gz
# 5Q6T.cif.gz
# 5Q6T.pdb.gz
# 5Q6T-sf.cif.gz
# 5Q6U.cif.gz
# 5Q6U.pdb.gz
# 5Q6U-sf.cif.gz
# 5Q6V.cif.gz
# 5Q6V.pdb.gz
# 5Q6V-sf.cif.gz
# 5Q6W.cif.gz
# 5Q6W.pdb.gz
# 5Q6W-sf.cif.gz
# 5Q6X.cif.gz
# 5Q6X.pdb.gz
# 5Q6X-sf.cif.gz
# 5Q6Y.cif.gz
# 5Q6Y.pdb.gz
# 5Q6Y-sf.cif.gz
# 5Q6Z.cif.gz
# 5Q6Z.pdb.gz
# 5Q6Z-sf.cif.gz
# 5Q70.cif.gz
# 5Q70.pdb.gz
# 5Q70-sf.cif.gz
# 5Q71.cif.gz
# 5Q71.pdb.gz
# 5Q71-sf.cif.gz
# 5Q72.cif.gz
# 5Q72.pdb.gz
# 5Q72-sf.cif.gz
# 5Q73.cif.gz
# 5Q73.pdb.gz
# 5Q73-sf.cif.gz
# 5Q74.cif.gz
# 6DBM.cif.gz
# 6DBM.pdb.gz
# 6DBM-sf.cif.gz
# 6DBN.cif.gz
# 6DBN.pdb.gz
# 6DBN-sf.cif.gz
# 6DR1.cif.gz
# 6DR1.pdb.gz
# 6DR1-sf.cif.gz
# 6DR7.cif.gz
# 6DR7.pdb.gz
# 6DR7-sf.cif.gz
# 6DR9.cif.gz
# 6DR9.pdb.gz
# 6DR9-sf.cif.gz
# 6DRB.cif.gz
# 6DRB.pdb.gz
# 6DRB-sf.cif.gz
# 6DRY.cif.gz
# 6DRY.pdb.gz
# 6DRY-sf.cif.gz
# 6DS6.cif.gz
# 6DS6.pdb.gz
# 6DS6-sf.cif.gz
# 6DT6.cif.gz
# 6DT6.pdb.gz
# 6DT6-sf.cif.gz
# 6DUP.cif.gz
# 6DUP.pdb.gz
# 6DUP-sf.cif.gz
# 6DVL.cif.gz
# 6DVL.pdb.gz
# 6DVL-sf.cif.gz
# 6DVM.cif.gz
# 6DVM.pdb.gz
# 6DVM-sf.cif.gz
# 6DVN.cif.gz
# 6DVN.pdb.gz
# 6DVN-sf.cif.gz
# 6DVO.cif.gz
# 6DVO.pdb.gz
# 6DVO-sf.cif.gz
# 6DW2.cif.gz
# 6DW2.pdb.gz
# 6DW2-sf.cif.gz
# 6DWA.cif.gz
# 6DWA.pdb.gz
# 6DWA-sf.cif.gz
# 6DWC.cif.gz
# 6DWC.pdb.gz
# 6DWC-sf.cif.gz
# 6DWI.cif.gz
# 6DWI.pdb.gz
# 6DWI-sf.cif.gz
# 6EDF.cif.gz
# 6EDF.pdb.gz
# 6EDF-sf.cif.gz
# 6EDI.cif.gz
# 6EDI.pdb.gz
# 6EDI-sf.cif.gz
# 6EE5.cif.gz
# 6EE5.pdb.gz
# 6EE5-sf.cif.gz
# 6EEG.cif.gz
# 6EEG.pdb.gz
# 6EEG-sf.cif.gz
# 6EEK.cif.gz
# 6EEK.pdb.gz
# 6EEK-sf.cif.gz
# 6EEP.cif.gz
# 6EEP.pdb.gz
# 6EEP-sf.cif.gz
# 6EFG.cif.gz
# 6EFG.pdb.gz
# 6EFG-sf.cif.gz
# 6EFH.cif.gz
# 6EFH.pdb.gz
# 6EFH-sf.cif.gz
# 6EIF.cif.gz
# 6EIF.pdb.gz
# 6EIF-sf.cif.gz
# 6EIJ.cif.gz
# 6EIJ.pdb.gz
# 6EIJ-sf.cif.gz
# 6EIL.cif.gz
# 6EIL.pdb.gz
# 6EIL-sf.cif.gz
# 6EIP.cif.gz
# 6EIP.pdb.gz
# 6EIP-sf.cif.gz
# 6EIQ.cif.gz
# 6EIQ.pdb.gz
# 6EIQ-sf.cif.gz
# 6EIR.cif.gz
# 6EIR.pdb.gz
# 6EIR-sf.cif.gz
# 6EIS.cif.gz
# 6EIS.pdb.gz
# 6EIS-sf.cif.gz
# 6EIV.cif.gz
# 6EIV.pdb.gz
# 6EIV-sf.cif.gz
# 6EJ4.cif.gz
# 6EJ4.pdb.gz
# 6EJ4-sf.cif.gz
# 6EPA.cif.gz
# 6EPA.pdb.gz
# 6EPA-sf.cif.gz
# 6ER1.cif.gz
# 6ER1.pdb.gz
# 6ER1-sf.cif.gz
# 6EZZ.cif.gz
# 6EZZ.pdb.gz
# 6EZZ-sf.cif.gz
# 6FGB.cif.gz
# 6FGB.pdb.gz
# 6FGB-sf.cif.gz
# 6FHJ.cif.gz
# 6FHJ.pdb.gz
# 6FHJ-sf.cif.gz
# 6FHN.cif.gz
# 6FHN.pdb.gz
# 6FHN-sf.cif.gz
# 6FLD.cif.gz
# 6FLD.pdb.gz
# 6FLD-sf.cif.gz
# 6FMR.cif.gz
# 6FMR.pdb.gz
# 6FMR-sf.cif.gz
# 6FQN.cif.gz
# 6FQN.pdb.gz
# 6FQN-sf.cif.gz
# 6FQO.cif.gz
# 6FQO.pdb.gz
# 6FQO-sf.cif.gz
# 6FQU.cif.gz
# 6FQU.pdb.gz
# 6FQU-sf.cif.gz
# 6FR0.cif.gz
# 6FR0.pdb.gz
# 6FR0-sf.cif.gz
# 6FRF.cif.gz
# 6FRF.pdb.gz
# 6FRF-sf.cif.gz
# 6G17.cif.gz
# 6G17.pdb.gz
# 6G17-sf.cif.gz
# 6G4M.cif.gz
# 6G4M.pdb.gz
# 6G4M-sf.cif.gz
# 6G4N.cif.gz
# 6G4N.pdb.gz
# 6G4N-sf.cif.gz
# 6G4O.cif.gz
# 6G4O.pdb.gz
# 6G4O-sf.cif.gz
# 6G4P.cif.gz
# 6G4P.pdb.gz
# 6G4P-sf.cif.gz
# 6GCA.cif.gz
# 6GCA.pdb.gz
# 6GCA-sf.cif.gz
# 6GCB.cif.gz
# 6GCB.pdb.gz
# 6GCB-sf.cif.gz
# 6GCC.cif.gz
# 6GCC.pdb.gz
# 6GCC-sf.cif.gz
# 6GD6.cif.gz
# 6GD6.pdb.gz
# 6GD6-sf.cif.gz
# 6GD7.cif.gz
# 6GD7.pdb.gz
# 6GD7-sf.cif.gz
# 6GD8.cif.gz
# 6GD8.pdb.gz
# 6GD8-sf.cif.gz
# 6GD9.cif.gz
# 6GD9.pdb.gz
# 6GD9-sf.cif.gz
# 6GF1.cif.gz
# 6GF1.pdb.gz
# 6GF1-sf.cif.gz
# 6GGO.cif.gz
# 6GGO.pdb.gz
# 6GGO-sf.cif.gz
# 6GGR.cif.gz
# 6GGR.pdb.gz
# 6GGR-sf.cif.gz
# 6GHS.cif.gz
# 6GHS.pdb.gz
# 6GHS-sf.cif.gz
# 6GOW.cif.gz
# 6GOW.pdb.gz
# 6GOW-sf.cif.gz
# 6GZD.cif.gz
# 6GZD.pdb.gz
# 6GZD-sf.cif.gz
# 6GZM.cif.gz
# 6GZM.pdb.gz
# 6GZM-sf.cif.gz
# 6H02.cif.gz
# 6H02.pdb.gz
# 6H02-sf.cif.gz
# 6H2P.cif.gz
# 6H2P.pdb.gz
# 6H2P-sf.cif.gz
# 6HCD.cif.gz
# 6HCD.pdb.gz
# 6HCD-sf.cif.gz
# 6HCE.cif.gz
# 6HCE.pdb.gz
# 6HCE-sf.cif.gz
# 6HCX.cif.gz
# 6HCX.pdb.gz
# 6HCX-sf.cif.gz
# 6HEB.cif.gz
# 6HEB.pdb.gz
# 6HEB-sf.cif.gz
# 6HEZ.cif.gz
# 6HEZ.pdb.gz
# 6HEZ-sf.cif.gz
# 6HF0.cif.gz
# 6HF0.pdb.gz
# 6HF0-sf.cif.gz
# 6HF3.cif.gz
# 6HF3.pdb.gz
# 6HF3-sf.cif.gz
# 6HFC.cif.gz
# 6HFC.pdb.gz
# 6HFC-sf.cif.gz
# 6HFY.cif.gz
# 6HFY.pdb.gz
# 6HFY-sf.cif.gz
# 6HG0.cif.gz
# 6HG0.pdb.gz
# 6HG0-sf.cif.gz
# 6HG5.cif.gz
# 6HG5.pdb.gz
# 6HG5-sf.cif.gz
# 5NBL.cif.gz
# 5NBL.pdb.gz
# 5NBL-sf.cif.gz
# 5NI5.cif.gz
# 5NI5.pdb.gz
# 5NI5-sf.cif.gz
# 5NI7.cif.gz
# 5NI7.pdb.gz
# 5NI7-sf.cif.gz
# 5NI8.cif.gz
# 5NI8.pdb.gz
# 5NI8-sf.cif.gz
# 5NIB.cif.gz
# 5NIB.pdb.gz
# 5NIB-sf.cif.gz
# 5OC8.cif.gz
# 5OC8.pdb.gz
# 5OC8-sf.cif.gz
# 5OCG.cif.gz
# 5OCG.pdb.gz
# 5OCG-sf.cif.gz
# 5OCO.cif.gz
# 5OCO.pdb.gz
# 5OCO-sf.cif.gz
# 5OCT.cif.gz
# 5OCT.pdb.gz
# 5OCT-sf.cif.gz
# 5ONM.cif.gz
# 5ONM.pdb.gz
# 5ONM-sf.cif.gz
# 5ONN.cif.gz
# 5ONN.pdb.gz
# 5ONN-sf.cif.gz
# 5ONO.cif.gz
# 5ONO.pdb.gz
# 5ONO-sf.cif.gz
# 5OW3.cif.gz
# 5OW3.pdb.gz
# 5OW3-sf.cif.gz
# 5Y7D.cif.gz
# 5Y7D.pdb.gz
# 5Y7D-sf.cif.gz
# 5Y7P.cif.gz
# 5Y7P.pdb.gz
# 5Y7P-sf.cif.gz
# 5YE3.cif.gz
# 5YE3.pdb.gz
# 5YE3-sf.cif.gz
# 5YE4.cif.gz
# 5YE4.pdb.gz
# 5YE4-sf.cif.gz
# 5YLO.cif.gz
# 5YLO.pdb.gz
# 5YLO-sf.cif.gz
# 5YSZ.cif.gz
# 5YSZ.pdb.gz
# 5YSZ-sf.cif.gz
# 5YTL.cif.gz
# 5YTL.pdb.gz
# 5YTL-sf.cif.gz
# 5YTM.cif.gz
# 5YTM.pdb.gz
# 5YTM-sf.cif.gz
# 5YTN.cif.gz
# 5YTN.pdb.gz
# 5YTN-sf.cif.gz
# 5YVD.cif.gz
# 5YVD.pdb.gz
# 5YVD-sf.cif.gz
# 5Z2C.cif.gz
# 5Z2C.pdb.gz
# 5Z2C-sf.cif.gz
# 5Z75.cif.gz
# 5Z75.pdb.gz
# 5Z75-sf.cif.gz
# 5Z76.cif.gz
# 5Z76.pdb.gz
# 5Z76-sf.cif.gz
# 5Z9G.cif.gz
# 5Z9G.pdb.gz
# 5Z9G-sf.cif.gz
# 5Z9H.cif.gz
# 5Z9H.pdb.gz
# 5Z9H-sf.cif.gz
# 5ZCW.cif.gz
# 5ZCW.pdb.gz
# 5ZCW-sf.cif.gz
# 5ZF6.cif.gz
# 5ZF6.pdb.gz
# 5ZF6-sf.cif.gz
# 5ZGE.cif.gz
# 5ZGE.pdb.gz
# 5ZGE-sf.cif.gz
# 5ZGF.cif.gz
# 5ZGF.pdb.gz
# 5ZGF-sf.cif.gz
# 5ZGI.cif.gz
# 5ZGI.pdb.gz
# 5ZGI-sf.cif.gz
# 5ZGP.cif.gz
# 5ZGP.pdb.gz
# 5ZGP-sf.cif.gz
# 5ZGQ.cif.gz
# 5ZGQ.pdb.gz
# 5ZGQ-sf.cif.gz
# 5ZGR.cif.gz
# 5ZGR.pdb.gz
# 5ZGR-sf.cif.gz
# 5ZGT.cif.gz
# 5ZGT.pdb.gz
# 5ZGT-sf.cif.gz
# 5ZGU.cif.gz
# 5ZGU.pdb.gz
# 5ZGU-sf.cif.gz
# 5ZGV.cif.gz
# 5ZGV.pdb.gz
# 5ZGV-sf.cif.gz
# 5ZGW.cif.gz
# 5ZGW.pdb.gz
# 5ZGW-sf.cif.gz
# 5ZGX.cif.gz
# 5ZGX.pdb.gz
# 5ZGX-sf.cif.gz
# 5ZGY.cif.gz
# 5ZGY.pdb.gz
# 5ZGY-sf.cif.gz
# 5ZGZ.cif.gz
# 5ZGZ.pdb.gz
# 5ZGZ-sf.cif.gz
# 5ZH1.cif.gz
# 5ZH1.pdb.gz
# 5ZH1-sf.cif.gz
# 5ZTZ.cif.gz
# 5ZTZ.pdb.gz
# 5ZTZ-sf.cif.gz
# 5ZU0.cif.gz
# 5ZU0.pdb.gz
# 5ZU0-sf.cif.gz
# 5ZXF.cif.gz
# 5ZXF.pdb.gz
# 5ZXF-sf.cif.gz
# 5ZZW.cif.gz
# 5ZZW.pdb.gz
# 5ZZW-sf.cif.gz
# 6A4U.cif.gz
# 6A4U.pdb.gz
# 6A4U-sf.cif.gz
# 6AA7.cif.gz
# 6AA7.pdb.gz
# 6AA7-sf.cif.gz
# 6AAA.cif.gz
# 6AAA.pdb.gz
# 6AAA-sf.cif.gz
# 6AOI.cif.gz
# 6AOI.pdb.gz
# 6AOI-sf.cif.gz
# 6AP9.cif.gz
# 6AP9.pdb.gz
# 6AP9-sf.cif.gz
# 6APA.cif.gz
# 6APA.pdb.gz
# 6APA-sf.cif.gz
# 6APN.cif.gz
# 6APN.pdb.gz
# 6APN-sf.cif.gz
# 6APZ.cif.gz
# 6APZ.pdb.gz
# 6APZ-sf.cif.gz
# 6AQ5.cif.gz
# 6AQ5.pdb.gz
# 6AQ5-sf.cif.gz
# 6AQ6.cif.gz
# 6AQ6.pdb.gz
# 6AQ6-sf.cif.gz
# 6AQK.cif.gz
# 6AQK.pdb.gz
# 6AQK-sf.cif.gz
# 6AR4.cif.gz
# 6AR4.pdb.gz
# 6AR4-sf.cif.gz
# 6ARH.cif.gz
# 6ARH.pdb.gz
# 6ARH-sf.cif.gz
# 6ARI.cif.gz
# 6ARI.pdb.gz
# 6ARI-sf.cif.gz
# 6ATM.cif.gz
# 6ATM.pdb.gz
# 6ATM-sf.cif.gz
# 6ATY.cif.gz
# 6ATY.pdb.gz
# 6ATY-sf.cif.gz
# 6AY7.cif.gz
# 6AY7.pdb.gz
# 6AY7-sf.cif.gz
# 6AY8.cif.gz
# 6AY8.pdb.gz
# 6AY8-sf.cif.gz
# 6BD4.cif.gz
# 6BD4.pdb.gz
# 6BD4-sf.cif.gz
# 6BN0.cif.gz
# 6BN0.pdb.gz
# 6BN0-sf.cif.gz
# 6BOJ.cif.gz
# 6BOJ.pdb.gz
# 6BOJ-sf.cif.gz
# 6BRX.cif.gz
# 6BRX.pdb.gz
# 6BRX-sf.cif.gz
# 6BS0.cif.gz
# 6BS0.pdb.gz
# 6BS0-sf.cif.gz
# 6BUU.cif.gz
# 6BUU.pdb.gz
# 6BUU-sf.cif.gz
# 6CHG.cif.gz
# 6CHG.pdb.gz
# 6CHG-sf.cif.gz
# 6CLU.cif.gz
# 6CLU.pdb.gz
# 6CLU-sf.cif.gz
# 6CLV.cif.gz
# 6CLV.pdb.gz
# 6CLV-sf.cif.gz
# 6CQP.cif.gz
# 6CQP.pdb.gz
# 6CQP-sf.cif.gz
# 6CR6.cif.gz
# 6CR6.pdb.gz
# 6CR6-sf.cif.gz
# 6CS8.cif.gz
# 6CS8.pdb.gz
# 6CS8-sf.cif.gz
# 6CVD.cif.gz
# 6CVD.pdb.gz
# 6CVD-sf.cif.gz
# 6DEF.cif.gz
# 6DEF.pdb.gz
# 6DEF-sf.cif.gz
# 6DI7.cif.gz
# 6DI7.pdb.gz
# 6DI7-sf.cif.gz
# 6DLX.cif.gz
# 6DLX.pdb.gz
# 6DLX-sf.cif.gz
# 6DOI.cif.gz
# 6DOI.pdb.gz
# 6DOI-sf.cif.gz
# 6DRU.cif.gz
# 6DRU.pdb.gz
# 6DRU-sf.cif.gz
# 6E49.cif.gz
# 6E49.pdb.gz
# 6E49-sf.cif.gz
# 6EAS.cif.gz
# 6EAS.pdb.gz
# 6EAS-sf.cif.gz
# 6ECM.cif.gz
# 6ECM.pdb.gz
# 6ECM-sf.cif.gz
# 6EDD.cif.gz
# 6EDD.pdb.gz
# 6EDD-sf.cif.gz
# 6EE0.cif.gz
# 6EE0.pdb.gz
# 6EE0-sf.cif.gz
# 6EOG.cif.gz
# 6EOG.pdb.gz
# 6EOG-sf.cif.gz
# 6EOL.cif.gz
# 6EOL.pdb.gz
# 6EOL-sf.cif.gz
# 6EP9.cif.gz
# 6EP9.pdb.gz
# 6EP9-sf.cif.gz
# 6ESN.cif.gz
# 6ESN.pdb.gz
# 6ESN-sf.cif.gz
# 6EZ1.cif.gz
# 6EZ1.pdb.gz
# 6EZ1-sf.cif.gz
# 6EZE.cif.gz
# 6EZE.pdb.gz
# 6EZE-sf.cif.gz
# 6F17.cif.gz
# 6F17.pdb.gz
# 6F17-sf.cif.gz
# 6F18.cif.gz
# 6F18.pdb.gz
# 6F18-sf.cif.gz
# 6F19.cif.gz
# 6F19.pdb.gz
# 6F19-sf.cif.gz
# 6F1A.cif.gz
# 6F1A.pdb.gz
# 6F1A-sf.cif.gz
# 6F5C.cif.gz
# 6F5C.pdb.gz
# 6F5C-sf.cif.gz
# 6FA1.cif.gz
# 6FA1.pdb.gz
# 6FA1-sf.cif.gz
# 6FA3.cif.gz
# 6FA3.pdb.gz
# 6FA3-sf.cif.gz
# 6FA4.cif.gz
# 6FA4.pdb.gz
# 6FA4-sf.cif.gz
# 6FAQ.cif.gz
# 6FAQ.pdb.gz
# 6FAQ-sf.cif.gz
# 6FDH.cif.gz
# 6FDH.pdb.gz
# 6FDH-sf.cif.gz
# 6FGQ.cif.gz
# 6FGQ.pdb.gz
# 6FGQ-sf.cif.gz
# 6FH8.cif.gz
# 6FH8.pdb.gz
# 6FH8-sf.cif.gz
# 6FQX.cif.gz
# 6FQX.pdb.gz
# 6FQX-sf.cif.gz
# 6FQY.cif.gz
# 6FQY.pdb.gz
# 6FQY-sf.cif.gz
# 6FQZ.cif.gz
# 6FQZ.pdb.gz
# 6FQZ-sf.cif.gz
# 6FXK.cif.gz
# 6FXK.pdb.gz
# 6FXK-sf.cif.gz
# 6FXM.cif.gz
# 6FXM.pdb.gz
# 6FXM-sf.cif.gz
# 6FXR.cif.gz
# 6FXR.pdb.gz
# 6FXR-sf.cif.gz
# 6FXT.cif.gz
# 6FXT.pdb.gz
# 6FXT-sf.cif.gz
# 6FXY.cif.gz
# 6FXY.pdb.gz
# 6FXY-sf.cif.gz
# 6FYJ.cif.gz
# 6FYJ.pdb.gz
# 6FYJ-sf.cif.gz
# 6G0V.cif.gz
# 6G0V.pdb.gz
# 6G0V-sf.cif.gz
# 6G5A.cif.gz
# 6G5A.pdb.gz
# 6G5A-sf.cif.gz
# 6G5B.cif.gz
# 6G5B.pdb.gz
# 6G5B-sf.cif.gz
# 6G5T.cif.gz
# 6G5T.pdb.gz
# 6G5T-sf.cif.gz
# 6GCN.cif.gz
# 6GCN.pdb.gz
# 6GCN-sf.cif.gz
# 6GKW.cif.gz
# 6GKW.pdb.gz
# 6GKW-sf.cif.gz
# 6GKX.cif.gz
# 6GKX.pdb.gz
# 6GKX-sf.cif.gz
# 6GME.cif.gz
# 6GME.pdb.gz
# 6GME-sf.cif.gz
# 6GMQ.cif.gz
# 6GMQ.pdb.gz
# 6GMQ-sf.cif.gz
# 6GP2.cif.gz
# 6GP2.pdb.gz
# 6GP2-sf.cif.gz
# 6GP3.cif.gz
# 6GP3.pdb.gz
# 6GP3-sf.cif.gz
# 6GS0.cif.gz
# 6GS0.pdb.gz
# 6GS0-sf.cif.gz
# 6GTA.cif.gz
# 6GTA.pdb.gz
# 6GTA-sf.cif.gz
# 6GVD.cif.gz
# 6GVD.pdb.gz
# 6GVD-sf.cif.gz
# 6GWF.cif.gz
# 6GWF.pdb.gz
# 6GWF-sf.cif.gz
# 6GWG.cif.gz
# 6GWG.pdb.gz
# 6GWG-sf.cif.gz
# 6GWS.cif.gz
# 6GWS.pdb.gz
# 6GWS-sf.cif.gz
# 6GX8.cif.gz
# 6GX8.pdb.gz
# 6GX8-sf.cif.gz
# 6GY9.cif.gz
# 6GY9.pdb.gz
# 6GY9-sf.cif.gz
# 6GYV.cif.gz
# 6GYV.pdb.gz
# 6GYV-sf.cif.gz
# 6H1Z.cif.gz
# 6H1Z.pdb.gz
# 6H1Z-sf.cif.gz
# 6H6Q.cif.gz
# 6H6Q.pdb.gz
# 6H6Q-sf.cif.gz
# 6H6R.cif.gz
# 6H6R.pdb.gz
# 6H6R-sf.cif.gz
# 6H8O.cif.gz
# 6H8O.pdb.gz
# 6H8O-sf.cif.gz
# 6H9S.cif.gz
# 6H9S.pdb.gz
# 6H9S-sf.cif.gz
# 6HA5.cif.gz
# 6HA5.pdb.gz
# 6HA5-sf.cif.gz
# 6HAQ.cif.gz
# 6HAQ.pdb.gz
# 6HAQ-sf.cif.gz
# 5NV1.cif.gz
# 5NV1.pdb.gz
# 5NV1-sf.cif.gz
# 5NVJ.cif.gz
# 5NVJ.pdb.gz
# 5NVJ-sf.cif.gz
# 5WAX.cif.gz
# 5WAX.pdb.gz
# 5WAX-sf.cif.gz
# 5XNC.cif.gz
# 5XNC.pdb.gz
# 5XNC-sf.cif.gz
# 5XNF.cif.gz
# 5XNF.pdb.gz
# 5XNF-sf.cif.gz
# 5XYB.cif.gz
# 5XYB.pdb.gz
# 5XYB-sf.cif.gz
# 5Y4T.cif.gz
# 5Y4T.pdb.gz
# 5Y4T-sf.cif.gz
# 5Y4U.cif.gz
# 5Y4U.pdb.gz
# 5Y4U-sf.cif.gz
# 5Y53.cif.gz
# 5Y53.pdb.gz
# 5Y53-sf.cif.gz
# 5Y5R.cif.gz
# 5Y5R.pdb.gz
# 5Y5R-sf.cif.gz
# 5Y5V.cif.gz
# 5Y5V.pdb.gz
# 5Y5V-sf.cif.gz
# 5Y6I.cif.gz
# 5Y6I.pdb.gz
# 5Y6I-sf.cif.gz
# 5Y6L.cif.gz
# 5Y6L.pdb.gz
# 5Y6L-sf.cif.gz
# 5Y6U.cif.gz
# 5Y6U.pdb.gz
# 5Y6U-sf.cif.gz
# 5YF4.cif.gz
# 5YF4.pdb.gz
# 5YF4-sf.cif.gz
# 5YYU.cif.gz
# 5YYU.pdb.gz
# 5YYU-sf.cif.gz
# 5Z84.cif.gz
# 5Z84.pdb.gz
# 5Z84-sf.cif.gz
# 5Z85.cif.gz
# 5Z85.pdb.gz
# 5Z85-sf.cif.gz
# 5Z86.cif.gz
# 5Z86.pdb.gz
# 5Z86-sf.cif.gz
# 5Z98.cif.gz
# 5Z98.pdb.gz
# 5Z98-sf.cif.gz
# 5ZCA.cif.gz
# 5ZCA.pdb.gz
# 5ZCA-sf.cif.gz
# 5ZCO.cif.gz
# 5ZCO.pdb.gz
# 5ZCO-sf.cif.gz
# 5ZCP.cif.gz
# 5ZCP.pdb.gz
# 5ZCP-sf.cif.gz
# 5ZCQ.cif.gz
# 5ZCQ.pdb.gz
# 5ZCQ-sf.cif.gz
# 5ZQY.cif.gz
# 5ZQY.pdb.gz
# 5ZQY-sf.cif.gz
# 5ZYF.cif.gz
# 5ZYF.pdb.gz
# 5ZYF-sf.cif.gz
# 6A8M.cif.gz
# 6A8M.pdb.gz
# 6A8M-sf.cif.gz
# 6AAH.cif.gz
# 6AAH.pdb.gz
# 6AAH-sf.cif.gz
# 6AAJ.cif.gz
# 6AAJ.pdb.gz
# 6AAJ-sf.cif.gz
# 6AAK.cif.gz
# 6AAK.pdb.gz
# 6AAK-sf.cif.gz
# 6AAM.cif.gz
# 6AAM.pdb.gz
# 6AAM-sf.cif.gz
# 6AMO.cif.gz
# 6AMO.pdb.gz
# 6AMO-sf.cif.gz
# 6AMT.cif.gz
# 6AMT.pdb.gz
# 6AMT-sf.cif.gz
# 6AMU.cif.gz
# 6AMU.pdb.gz
# 6AMU-sf.cif.gz
# 6AN2.cif.gz
# 6AN2.pdb.gz
# 6AN2-sf.cif.gz
# 6AN4.cif.gz
# 6AN4.pdb.gz
# 6AN4-sf.cif.gz
# 6AN6.cif.gz
# 6AN6.pdb.gz
# 6AN6-sf.cif.gz
# 6AN8.cif.gz
# 6AN8.pdb.gz
# 6AN8-sf.cif.gz
# 6ANQ.cif.gz
# 6ANQ.pdb.gz
# 6ANQ-sf.cif.gz
# 6ASW.cif.gz
# 6ASW.pdb.gz
# 6ASW-sf.cif.gz
# 6AVM.cif.gz
# 6AVM.pdb.gz
# 6AVM-sf.cif.gz
# 6AVT.cif.gz
# 6AVT.pdb.gz
# 6AVT-sf.cif.gz
# 6BFG.cif.gz
# 6BFG.pdb.gz
# 6BFG-sf.cif.gz
# 6BOQ.cif.gz
# 6BOQ.pdb.gz
# 6BOQ-sf.cif.gz
# 6BOR.cif.gz
# 6BOR.pdb.gz
# 6BOR-sf.cif.gz
# 6BOS.cif.gz
# 6BOS.pdb.gz
# 6BOS-sf.cif.gz
# 6BOT.cif.gz
# 6BOT.pdb.gz
# 6BOT-sf.cif.gz
# 6BOU.cif.gz
# 6BOU.pdb.gz
# 6BOU-sf.cif.gz
# 6BOV.cif.gz
# 6BOV.pdb.gz
# 6BOV-sf.cif.gz
# 6BOW.cif.gz
# 6BOW.pdb.gz
# 6BOW-sf.cif.gz
# 6BP6.cif.gz
# 6BP6.pdb.gz
# 6BP6-sf.cif.gz
# 6BRW.cif.gz
# 6BRW.pdb.gz
# 6BRW-sf.cif.gz
# 6BSS.cif.gz
# 6BSS.pdb.gz
# 6BSS-sf.cif.gz
# 6C10.cif.gz
# 6C10.pdb.gz
# 6C10-sf.cif.gz
# 6C4Y.cif.gz
# 6C4Y.pdb.gz
# 6C4Y-sf.cif.gz
# 6C50.cif.gz
# 6C50-sf.cif.gz
# 6C51.cif.gz
# 6C51.pdb.gz
# 6C51-sf.cif.gz
# 6C52.cif.gz
# 6C52.pdb.gz
# 6C52-sf.cif.gz
# 6C7D.cif.gz
# 6C7D.pdb.gz
# 6C7D-sf.cif.gz
# 6C7E.cif.gz
# 6C7E.pdb.gz
# 6C7E-sf.cif.gz
# 6C7F.cif.gz
# 6C7F.pdb.gz
# 6C7F-sf.cif.gz
# 6C7G.cif.gz
# 6C7G.pdb.gz
# 6C7G-sf.cif.gz
# 6C7I.cif.gz
# 6C7I.pdb.gz
# 6C7I-sf.cif.gz
# 6C7J.cif.gz
# 6C7J.pdb.gz
# 6C7J-sf.cif.gz
# 6CGY.cif.gz
# 6CGY.pdb.gz
# 6CGY-sf.cif.gz
# 6CGZ.cif.gz
# 6CGZ.pdb.gz
# 6CGZ-sf.cif.gz
# 6CH0.cif.gz
# 6CH0.pdb.gz
# 6CH0-sf.cif.gz
# 6CJK.cif.gz
# 6CJK.pdb.gz
# 6CJK-sf.cif.gz
# 6CWC.cif.gz
# 6CWC.pdb.gz
# 6CWC-sf.cif.gz
# 6CWF.cif.gz
# 6CWF.pdb.gz
# 6CWF-sf.cif.gz
# 6CWH.cif.gz
# 6CWH.pdb.gz
# 6CWH-sf.cif.gz
# 6CWI.cif.gz
# 6CWI.pdb.gz
# 6CWI-sf.cif.gz
# 6CWL.cif.gz
# 6CWL.pdb.gz
# 6CWL-sf.cif.gz
# 6CWM.cif.gz
# 6CWM.pdb.gz
# 6CWM-sf.cif.gz
# 6CWN.cif.gz
# 6CWN.pdb.gz
# 6CWN-sf.cif.gz
# 6CWR.cif.gz
# 6CWR.pdb.gz
# 6CWR-sf.cif.gz
# 6CZ7.cif.gz
# 6CZ7.pdb.gz
# 6CZ7-sf.cif.gz
# 6CZ8.cif.gz
# 6CZ8.pdb.gz
# 6CZ8-sf.cif.gz
# 6CZ9.cif.gz
# 6CZ9.pdb.gz
# 6CZ9-sf.cif.gz
# 6CZA.cif.gz
# 6CZA.pdb.gz
# 6CZA-sf.cif.gz
# 6CZL.cif.gz
# 6CZL.pdb.gz
# 6CZL-sf.cif.gz
# 6CZM.cif.gz
# 6CZM.pdb.gz
# 6CZM-sf.cif.gz
# 6D0O.cif.gz
# 6D0O.pdb.gz
# 6D0O-sf.cif.gz
# 6D1O.cif.gz
# 6D1O.pdb.gz
# 6D1O-sf.cif.gz
# 6D3H.cif.gz
# 6D3H.pdb.gz
# 6D3H-sf.cif.gz
# 6D3M.cif.gz
# 6D3M.pdb.gz
# 6D3M-sf.cif.gz
# 6DF3.cif.gz
# 6DF3.pdb.gz
# 6DF3-sf.cif.gz
# 6DGK.cif.gz
# 6DGK.pdb.gz
# 6DGK-sf.cif.gz
# 6DMN.cif.gz
# 6DMN.pdb.gz
# 6DMN-sf.cif.gz
# 6DMV.cif.gz
# 6DMV.pdb.gz
# 6DMV-sf.cif.gz
# 6DO8.cif.gz
# 6DO8.pdb.gz
# 6DO8-sf.cif.gz
# 6DO9.cif.gz
# 6DO9.pdb.gz
# 6DO9-sf.cif.gz
# 6DOA.cif.gz
# 6DOA.pdb.gz
# 6DOA-sf.cif.gz
# 6DOB.cif.gz
# 6DOB.pdb.gz
# 6DOB-sf.cif.gz
# 6DOC.cif.gz
# 6DOC.pdb.gz
# files

# %%
import shutil
import os

source_folder = "/content/batch_04"
destination_base_folder = "/content/drive/MyDrive/IontheFold/downloads/70-80K"

# Create the destination base folder if it doesn't exist
if not os.path.exists(destination_base_folder):
    os.makedirs(destination_base_folder)

# The destination path for the source folder
destination_folder_path = os.path.join(destination_base_folder, os.path.basename(source_folder))

# Check if the source folder exists
if not os.path.exists(source_folder):
    print(f"Error: Source folder '{source_folder}' not found.")
else:
    try:
        shutil.move(source_folder, destination_base_folder)
        print(f"Successfully moved folder '{source_folder}' to '{destination_base_folder}'")
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# Successfully moved folder '/content/batch_04' to '/content/drive/MyDrive/IontheFold/downloads/70-80K'

# %% [markdown]
# I have modified the `split_files` function in the first code cell (`8Fae-LfmuCde`) to allow specifying a starting batch number.
#
# Here are the key changes:
#
# *   Added a `start_batch_num` parameter to the `split_files` function, defaulting to 1.
# *   Calculated the `start_index` in the list of files based on the `start_batch_num` and `batch_size`.
# *   Added a check to see if the `start_index` is valid (i.e., not beyond the total number of files).
# *   Adjusted the loop to start from the calculated `start_index`.
# *   Modified the batch folder naming to correctly number the batches starting from `start_batch_num`.
# *   Added print statements to show the starting index and batch number being processed.
# *   Updated the usage example at the bottom of the cell to call `split_files` with `start_batch_num=5` and the source folder `/content/drive/MyDrive/IontheFold/downloads/70-80K` as both the source and output directory.
#
# You can now run the first code cell to split the remaining files into batch folders starting from `batch_05` within the `/content/drive/MyDrive/IontheFold/downloads/70-80K` folder.

# %% [markdown]
# # Task
# Combine the content of every 10 subfolders (named batch_XX, starting from batch_05 up to batch_57) within the directory "/content/drive/MyDrive/IontheFold/downloads/70-80K" into new folders named sequentially (folder_1, folder_2, folder_3, etc.) within the same parent directory.

# %% [markdown]
# ## List batch folders
#
# ### Subtask:
# Get a list of all the existing batch folders in the source directory.

# %% [markdown]
# **Reasoning**:
# List all entries in the source directory and filter for directories starting with "batch_".

# %%
import os

source_directory = "/content/drive/MyDrive/IontheFold/downloads/70-80K"

# Get all entries in the source directory
all_entries = os.listdir(source_directory)

# Filter for entries that are directories and start with "batch_"
batch_folders = sorted([
    entry for entry in all_entries
    if os.path.isdir(os.path.join(source_directory, entry)) and entry.startswith("batch_")
])

print(f"Found {len(batch_folders)} batch folders:")
for folder in batch_folders:
    print(folder)
# Out:
# Found 53 batch folders:
# batch_05
# batch_06
# batch_07
# batch_08
# batch_09
# batch_10
# batch_11
# batch_12
# batch_13
# batch_14
# batch_15
# batch_16
# batch_17
# batch_18
# batch_19
# batch_20
# batch_21
# batch_22
# batch_23
# batch_24
# batch_25
# batch_26
# batch_27
# batch_28
# batch_29
# batch_30
# batch_31
# batch_32
# batch_33
# batch_34
# batch_35
# batch_36
# batch_37
# batch_38
# batch_39
# batch_40
# batch_41
# batch_42
# batch_43
# batch_44
# batch_45
# batch_46
# batch_47
# batch_48
# batch_49
# batch_50
# batch_51
# batch_52
# batch_53
# batch_54
# batch_55
# batch_56
# batch_57

# %%
# Group batch folders into sets of 10
batch_group_size = 10
grouped_batches = [
    batch_folders[i:i + batch_group_size]
    for i in range(0, len(batch_folders), batch_group_size)
]

print(f"Grouped {len(batch_folders)} folders into {len(grouped_batches)} groups of {batch_group_size}:")
for i, group in enumerate(grouped_batches):
    print(f"Group {i+1}: {group}")
# Out:
# Grouped 53 folders into 6 groups of 10:
# Group 1: ['batch_05', 'batch_06', 'batch_07', 'batch_08', 'batch_09', 'batch_10', 'batch_11', 'batch_12', 'batch_13', 'batch_14']
# Group 2: ['batch_15', 'batch_16', 'batch_17', 'batch_18', 'batch_19', 'batch_20', 'batch_21', 'batch_22', 'batch_23', 'batch_24']
# Group 3: ['batch_25', 'batch_26', 'batch_27', 'batch_28', 'batch_29', 'batch_30', 'batch_31', 'batch_32', 'batch_33', 'batch_34']
# Group 4: ['batch_35', 'batch_36', 'batch_37', 'batch_38', 'batch_39', 'batch_40', 'batch_41', 'batch_42', 'batch_43', 'batch_44']
# Group 5: ['batch_45', 'batch_46', 'batch_47', 'batch_48', 'batch_49', 'batch_50', 'batch_51', 'batch_52', 'batch_53', 'batch_54']
# Group 6: ['batch_55', 'batch_56', 'batch_57']

# %%
import os
import shutil

def merge_batch_group(source_directory, batch_list, destination_directory):
    """
    Merges the contents of a list of specified batch folders into a single destination directory.

    Args:
        source_directory (str): The path to the directory containing the batch folders.
        batch_list (list): A list of batch folder names (strings) to merge.
        destination_directory (str): The path to the directory where contents will be merged.
    """
    if not os.path.exists(source_directory):
        print(f"Error: Source directory '{source_directory}' not found.")
        return

    # Create the destination directory if it doesn't exist
    if not os.path.exists(destination_directory):
        os.makedirs(destination_directory)
        print(f"Created destination directory: '{destination_directory}'")

    print(f"Merging contents of batches {batch_list} into '{destination_directory}'...")

    for batch_name in batch_list:
        batch_path = os.path.join(source_directory, batch_name)

        if os.path.isdir(batch_path):
            print(f"Processing batch folder: '{batch_path}'")
            try:
                # Iterate through contents of the batch folder and move them
                for content_name in os.listdir(batch_path):
                    source_content_path = os.path.join(batch_path, content_name)
                    destination_content_path = os.path.join(destination_directory, content_name)

                    # Move the item
                    shutil.move(source_content_path, destination_content_path)
                    # print(f"Moved '{content_name}' to '{destination_directory}'") # Uncomment for verbose output
            except FileNotFoundError:
                 print(f"Warning: Content not found in '{batch_path}'. It might have already been moved.")
            except shutil.Error as e:
                print(f"Error moving content from '{batch_path}' to '{destination_directory}': {e}")
            except Exception as e:
                print(f"An unexpected error occurred while processing '{batch_path}': {e}")
        else:
            print(f"Warning: '{batch_path}' is not a directory or does not exist. Skipping.")


# --- Main merging loop ---
source_directory = "/content/drive/MyDrive/IontheFold/downloads/70-80K" # Directory containing the batch folders
output_base_directory = "/content/drive/MyDrive/IontheFold/downloads/70-80K" # Base directory for the new merged folders

for i, batch_group in enumerate(grouped_batches):
    # Create sequential folder names like folder_1, folder_2, etc.
    merged_folder_name = f"folder_{i+1}"
    merged_destination_path = os.path.join(output_base_directory, merged_folder_name)

    # Call the function to merge the current group of batches
    merge_batch_group(source_directory, batch_group, merged_destination_path)

print("\nMerging process complete.")
# Out:
# Merging contents of batches ['batch_05', 'batch_06', 'batch_07', 'batch_08', 'batch_09', 'batch_10', 'batch_11', 'batch_12', 'batch_13', 'batch_14'] into '/content/drive/MyDrive/IontheFold/downloads/70-80K/folder_1'...
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_05'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_06'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_07'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_08'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_09'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_10'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_11'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_12'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_13'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_14'
# Merging contents of batches ['batch_15', 'batch_16', 'batch_17', 'batch_18', 'batch_19', 'batch_20', 'batch_21', 'batch_22', 'batch_23', 'batch_24'] into '/content/drive/MyDrive/IontheFold/downloads/70-80K/folder_2'...
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_15'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_16'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_17'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_18'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_19'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_20'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_21'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_22'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_23'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_24'
# Merging contents of batches ['batch_25', 'batch_26', 'batch_27', 'batch_28', 'batch_29', 'batch_30', 'batch_31', 'batch_32', 'batch_33', 'batch_34'] into '/content/drive/MyDrive/IontheFold/downloads/70-80K/folder_3'...
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_25'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_26'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_27'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_28'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_29'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_30'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_31'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_32'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_33'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_34'
# Merging contents of batches ['batch_35', 'batch_36', 'batch_37', 'batch_38', 'batch_39', 'batch_40', 'batch_41', 'batch_42', 'batch_43', 'batch_44'] into '/content/drive/MyDrive/IontheFold/downloads/70-80K/folder_4'...
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_35'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_36'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_37'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_38'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_39'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_40'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_41'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_42'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_43'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_44'
# Merging contents of batches ['batch_45', 'batch_46', 'batch_47', 'batch_48', 'batch_49', 'batch_50', 'batch_51', 'batch_52', 'batch_53', 'batch_54'] into '/content/drive/MyDrive/IontheFold/downloads/70-80K/folder_5'...
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_45'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_46'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_47'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_48'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_49'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_50'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_51'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_52'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_53'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_54'
# Merging contents of batches ['batch_55', 'batch_56', 'batch_57'] into '/content/drive/MyDrive/IontheFold/downloads/70-80K/folder_6'...
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_55'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_56'
# Processing batch folder: '/content/drive/MyDrive/IontheFold/downloads/70-80K/batch_57'
#
# Merging process complete.
